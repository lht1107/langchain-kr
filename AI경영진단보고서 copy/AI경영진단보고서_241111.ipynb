# %% [markdown]
# ## 0. 전반적인 Process
#
# - 현황
#   - 샘플 데이터를 활용한 Prompt Engineering 수행 중
# - 과제
#   - Postgre DB 연계 필요
#   - BPI 연계 필요

# %%
from IPython.display import Image, display
import base64

def mm(graph: str) -> None:
    """
    Mermaid 그래프를 이미지로 렌더링하여 표시합니다.

    이 함수는 Mermaid 문법으로 작성된 그래프 문자열을 받아
    base64로 인코딩한 후, Mermaid 온라인 렌더링 서비스를 통해
    이미지로 변환하여 Jupyter Notebook이나 유사한 환경에서 표시합니다.

    Args:
        graph (str): Mermaid 문법으로 작성된 그래프 문자열

    Returns:
        None: 이미지를 직접 표시하므로 반환값은 없습니다.

    Example:
        mm('''
        graph TD
        A[Start] --> B{Is it?}
        B -- Yes --> C[OK]
        B -- No --> D[End]
        ''')
    """
    # 그래프 문자열을 UTF-8로 인코딩
    graphbytes = graph.encode("utf-8")
    
    # 인코딩된 바이트를 base64로 변환
    base64_bytes = base64.b64encode(graphbytes)
    
    # base64 바이트를 ASCII 문자열로 디코딩
    base64_string = base64_bytes.decode("ascii")
    
    # Mermaid 온라인 렌더링 서비스 URL과 base64 문자열을 결합하여 이미지 표시
    display(Image(url="https://mermaid.ink/img/" + base64_string))

mm("""
graph LR
    A[API Key 등 협업 / 기획] --> B[DB 연계]
    B --> C[BPI 계산]
    C --> D[강약점 선택]
    D --> E[강약점 데이터전처리]
    E --> F[Prompt Engineering]
    F --> G[완료]
""")
# Out:
# <img src="https://mermaid."/>

# %% [markdown]
# ## 1. 필수 라이브러리 임포트 및 환경 설정
#
# - .env 파일에 '자신' 또는 '더존' api key 저장:
#   - OPENAI_API_KEY=sk-proj-.....

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnableParallel, RunnableMap, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser
from typing import Dict, Any, Literal
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain.callbacks.base import BaseCallbackHandler
from langchain.cache import SQLiteCache
from operator import itemgetter
from tabulate import tabulate
from langchain.callbacks import get_openai_callback
from langchain_teddynote import logging

# env 파일 읽기
load_dotenv()

# OpenAI API 키 가져오기
openai_api_key = os.getenv("OPENAI_API_KEY")

# 프로젝트 이름을 입력합니다.
logging.langsmith("AI경영진단보고서")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# AI경영진단보고서

# %% [markdown]
# ## 2. Sample Data 생성
#
# - 데이터 출력 방식은 협의 필요 (\w 조희성 과장님, 이도은 대리님)
# - 현재 출력물
#   - df_company_info : 회사명, 업종, 재무/회계 데이터
#   - df_partner_info : df_company_info의 회사의 매입/매출 거래처 정보 등
# - 향후 : Postgre DB와 연계

# %%
import pandas as pd
import numpy as np

# 접근 시점 정의
ACCESS_TIME = '2024-11-01'
access_datetime = pd.to_datetime(ACCESS_TIME)

# 재현 가능성을 위해 난수 생성기의 시드를 설정합니다.
np.random.seed(42)

# 회사 및 업종 정보 생성
num_companies = 100  # 총 100개의 회사 생성
company_names = [f'Company_{i+1}' for i in range(num_companies)]  # 회사명 리스트 생성 (Company_1, Company_2, ..., Company_100)
industries = ['Manufacturing', 'Retail', 'Technology', 'Healthcare', 'Finance']  # 업종 리스트 정의

# 각 회사에 대한 고정된 업종 리스트 생성
company_industries = [np.random.choice(industries) for _ in range(num_companies)]  

# 날짜 생성 (2020-01 ~ ACCESS_TIME 기준 한 달 전까지)
dates = pd.date_range(start="2020-01-01", end=access_datetime - pd.DateOffset(months=1), freq='MS').strftime("%Y-%m").tolist()

# 상위 매출처 및 매입처 정보 생성 함수 정의
sales_partner_pool = list(set(f'SalesPartner_{i+1}' for i in range(8)))  # 매출처 Pool 생성 (8개)
purchase_partner_pool = list(set(f'PurchasePartner_{i+1}' for i in range(8)))  # 매입처 Pool 생성 (8개)

# 각 회사별 기본 인원수를 설정합니다.
company_base_employees = {company: np.random.randint(100, 300) for company in company_names}  # 기업별로 100명 ~ 300명 사이의 기본 인원수 설정

def generate_partner_data():
    """
    상위 매출처 및 매입처 정보를 생성하는 함수입니다.
    
    Returns:
        dict: 생성된 매출처 및 매입처 정보 딕셔너리 리스트
    """
    # 상위 5개 매출처 및 매입처 무작위 선택
    sales_companies = list(np.random.choice(sales_partner_pool, 5, replace=False))
    sales_grades = list(np.random.choice(['AAA', 'AA+', 'AA', 'A+', 'A', 'BBB+', 'BBB', 'BB', 'B', 'CCC-'], 5, replace=False))

    purchase_companies = list(np.random.choice(purchase_partner_pool, 5, replace=False))
    purchase_grades = list(np.random.choice(['AAA', 'AA+', 'AA', 'A+', 'A', 'BBB+', 'BBB', 'BB', 'B', 'CCC-'], 5, replace=False))

    # 매출처 및 매입처 정보 딕셔너리 리스트로 생성
    sales_partners = [
        {
            "매출처_회사명": sales_companies[i],
            "매출처_신용등급": sales_grades[i],
            "매출처_매출금액": int(np.random.uniform(1000, 10000)),  # 월별 매출금액 (1000만원 ~ 10000만원)
            "매출처_회수금액": int(np.random.uniform(500, 5000)),  # 월별 회수금액 (500만원 ~ 5000만원)
            "매출처_회수기일": int(np.random.uniform(30, 90)),  # 월별 회수기일 (30일 ~ 90일)
        }
        for i in range(5)
    ]

    purchase_partners = [
        {
            "매입처_회사명": purchase_companies[i],
            "매입처_신용등급": purchase_grades[i],
            "매입처_매입금액": int(np.random.uniform(1000, 10000)),  # 월별 매입금액 (1000만원 ~ 10000만원)
            "매입처_지급금액": int(np.random.uniform(100, 1000)),  # 월별 지급금액 (100만원 ~ 1000만원)
            "매입처_지급기일": int(np.random.uniform(30, 90)),  # 월별 회수기일 (30일 ~ 90일)
        }
        for i in range(5)
    ]

    return sales_partners, purchase_partners

# 기본 정보 데이터 생성 함수 정의
def generate_basic_data(company, industry, date):
    """
    각 회사의 특정 날짜에 대한 기본 재무 데이터를 생성하는 함수입니다.
    
    Args:
        company (str): 회사명
        industry (str): 업종명
        date (str): 날짜 (YYYY-MM 형식)
    
    Returns:
        dict: 생성된 회사의 기본 재무 정보 및 상위 매출처, 매입처 정보
    """
    base_asset_value = 30000  # 기본 총자산 값 설정 (3억원)
    total_assets = round(base_asset_value * (1 + np.random.normal(0, 0.05)), 0)  # 기본 총자산 값에서 5% 변동 (정규분포 이용, 소수점 없이)
    revenue = round(np.random.uniform(1000, 10000), 0)  # 매출액은 1천만원 ~ 1억원 사이의 값으로 설정 (소수점 없이)
    operating_profit = round(revenue * np.random.uniform(-0.2, 0.2), 0)  # 영업이익은 매출액의 -20%~20% 범위로 설정 (소수점 없이)
    net_income = round(operating_profit * np.random.uniform(-0.5, 0.8), 0)  # 당기순이익은 영업이익의 -50%~80% 범위로 설정 (소수점 없이)
    short_term_loans = round(np.random.uniform(500, 5000), 0)  # 단기차입금은 500만원 ~ 5000만원 범위로 설정 (소수점 없이)
    long_term_loans = round(np.random.uniform(1000, 10000), 0)  # 장기차입금은 1000만원 ~ 1억원 범위로 설정 (소수점 없이)
    total_loans = short_term_loans + long_term_loans  # 총 차입금 계산
    loan_to_sales = round((total_loans / revenue) * 100, 2)  # 매출대비차입금 비율을 백분율로 계산
    working_capital_turnover = round(np.random.uniform(1, 5), 2)  # 운전자금회전율은 1~5회 사이의 값으로 설정
    operating_cash_flow = round(np.random.uniform(500, 5000), 0)  # 영업활동현금흐름은 500만원 ~ 5000만원 범위로 설정 (소수점 없이)
    net_cash_flow = round(operating_cash_flow - total_loans, 0)  # 순현금흐름 = 영업활동현금흐름 - 총 차입금 (소수점 없이)
    ar_balance = round(np.random.uniform(1000, 5000), 0)  # 매출채권 규모 (1000만원 ~ 5000만원)
    ap_balance = round(np.random.uniform(800, 4000), 0)  # 매입채무 규모 (800만원 ~ 4000만원)
    inventory = round(np.random.uniform(2000, 10000), 0)  # 재고자산 (2000만원 ~ 1억원)
    current_assets = round(np.random.uniform(15000, 30000), 0)  # 유동자산 (1.5억원 ~ 3억원)
    current_liabilities = round(np.random.uniform(10000, 25000), 0)  # 유동부채 (1억원 ~ 2.5억원)

    # 상위 매출처 및 매입처 정보 생성
    sales_partners, purchase_partners = generate_partner_data()

    # 기본 인원수를 기반으로 ±10% 내외의 변동을 줍니다.
    base_employees = company_base_employees[company]
    employees = round(base_employees * (1 + np.random.uniform(-0.1, 0.1)))  # ±10% 내외 변동

    return {
        '기업명': company,
        '업종': industry,
        '날짜': date,
        '매출액증가율': round(np.random.uniform(5, 15), 2),  # 매출액증가율 (5% ~ 15% 사이)
        '총자산증가율': round(np.random.uniform(3, 10), 2),  # 총자산증가율 (3% ~ 10% 사이)
        '총자산': int(total_assets),  # 총자산 (정수형)
        '매출액': int(revenue),  # 매출액 (정수형)
        '영업이익': int(operating_profit),  # 영업이익 (정수형)
        '영업이익률': round(operating_profit / revenue * 100, 2) if revenue != 0 else round(np.random.uniform(-20, 20), 2),  # 영업이익률 (백분율)
        '당기순이익': int(net_income),  # 당기순이익 (정수형)
        '당기순이익률': round(net_income / revenue * 100, 2) if revenue != 0 else round(np.random.uniform(-30, 30), 2),  # 당기순이익률 (백분율)
        '단기차입금': int(short_term_loans),  # 단기차입금 (정수형)
        '장기차입금': int(long_term_loans),  # 장기차입금 (정수형)
        '유동자산': int(current_assets),  # 유동자산 (정수형)
        '유동부채': int(current_liabilities),  # 유동부채 (정수형)
        '매출대비차입금': loan_to_sales,  # 매출대비차입금 비율 (백분율)
        '운전자금회전율': working_capital_turnover,  # 운전자금회전율
        '인원수': employees,  # 인원수 (±10% 변동)
        '월평균급여액': round(np.random.uniform(200, 500), 1),  # 월평균 급여액 (200 ~ 500만원)
        '월매출창출액': round(np.random.uniform(5000, 20000), 1),  # 월 매출 창출액 (5000 ~ 20000만원)
        '영업활동현금흐름/매출액': round(np.random.uniform(0.05, 0.2), 2),  # 영업활동현금흐름/매출액 비율 (5% ~ 20%)
        '영업활동현금흐름': int(operating_cash_flow),  # 영업활동현금흐름 (정수형)
        '순현금흐름': int(net_cash_flow),  # 순현금흐름 (정수형)
        '매출채권': int(ar_balance),  # 매출채권 (정수형)
        '매입채무': int(ap_balance),  # 매입채무 (정수형)
        '재고자산': int(inventory),  # 재고자산 (정수형)
        '상위_매출처': sales_partners,  # 상위 매출처 정보
        '상위_매입처': purchase_partners  # 상위 매입처 정보
    }

# 기본 정보 데이터 생성
# 각 회사와 날짜별로 기본 재무 데이터를 생성하여 리스트로 저장
basic_data = [
    generate_basic_data(company, industry, date)
    for company, industry in zip(company_names, company_industries)
    for date in dates
]

# 기본 정보 데이터프레임 생성
df_company_info = pd.DataFrame(basic_data)  # 회사 기본 정보로 데이터프레임 생성

# 데이터프레임 샘플 출력
print(df_company_info[['기업명', '날짜', '상위_매출처', '상위_매입처']].head())
# Out:
#          기업명       날짜                                             상위_매출처  \
# 0  Company_1  2020-01  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'A'...
# 1  Company_1  2020-02  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'BB...
# 2  Company_1  2020-03  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'AA...
# 3  Company_1  2020-04  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'BB...
# 4  Company_1  2020-05  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'A'...
#
#                                               상위_매입처
# 0  [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 1  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 2  [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 3  [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 4  [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...

# %% [markdown]
# - Company_1에 대한 샘플 데이터

# %%
from pprint import pprint

print('#'*10, 'Company_1에 대한 정보', '#'*10)
pprint(df_company_info[df_company_info['기업명']== 'Company_1'])

df_company_info.to_csv("sample.csv", encoding='utf-8-sig', index=False)
# Out:
# ########## Company_1에 대한 정보 ##########
#           기업명          업종       날짜  매출액증가율  총자산증가율    총자산   매출액  영업이익  영업이익률  \
# 0   Company_1  Healthcare  2020-01    7.24    7.99  29011  3508   573  16.33
# 1   Company_1  Healthcare  2020-02   13.90    5.37  30006  6847   956  13.96
# 2   Company_1  Healthcare  2020-03    5.15    9.53  29941  5884  -502  -8.53
# 3   Company_1  Healthcare  2020-04   11.02    6.88  29198  6543  1162  17.76
# 4   Company_1  Healthcare  2020-05    8.53    7.09  32720  9718   731   7.52
# 5   Company_1  Healthcare  2020-06   13.05    9.32  30607  7283   105   1.44
# 6   Company_1  Healthcare  2020-07    5.30    9.07  31235  1819   165   9.07
# 7   Company_1  Healthcare  2020-08    5.52    5.36  33079  7637  -971 -12.71
# 8   Company_1  Healthcare  2020-09    6.11    8.93  31509  3292   239   7.26
# 9   Company_1  Healthcare  2020-10    7.20    4.49  29135  2349  -254 -10.81
# 10  Company_1  Healthcare  2020-11    8.80    7.13  31661  5816  -734 -12.62
# 11  Company_1  Healthcare  2020-12    5.31    4.84  30264  5968  -152  -2.55
# 12  Company_1  Healthcare  2021-01   13.86    7.31  27466  7938 -1249 -15.73
# 13  Company_1  Healthcare  2021-02   11.23    8.24  31481  1191   179  15.03
# 14  Company_1  Healthcare  2021-03   11.33    9.52  26631  3457   -32  -0.93
# 15  Company_1  Healthcare  2021-04   14.21    7.32  28682  1611  -128  -7.95
# 16  Company_1  Healthcare  2021-05   12.25    7.15  30562  4873  -584 -11.98
# 17  Company_1  Healthcare  2021-06    8.25    8.41  28864  3961   -47  -1.19
# 18  Company_1  Healthcare  2021-07   11.90    7.74  30115  4033   531  13.17
# 19  Company_1  Healthcare  2021-08   14.34    5.46  28076  6861 -1080 -15.74
# 20  Company_1  Healthcare  2021-09   13.19    7.22  28517  8227   129   1.57
# 21  Company_1  Healthcare  2021-10   14.42    9.11  28345  3384   197   5.82
# 22  Company_1  Healthcare  2021-11    7.29    4.63  27009  5510  -227  -4.12
# 23  Company_1  Healthcare  2021-12   11.59    8.61  31828  8632   775   8.98
# 24  Company_1  Healthcare  2022-01   11.85    3.64  28846  9924  1869  18.83
# 25  Company_1  Healthcare  2022-02   13.05    4.89  26592  4081  -141  -3.46
# 26  Company_1  Healthcare  2022-03   12.59    6.15  29745  8064   670   8.31
# 27  Company_1  Healthcare  2022-04    6.26    7.62  29320  1303  -228 -17.50
# 28  Company_1  Healthcare  2022-05    8.58    6.46  32374  6022   126   2.09
# 29  Company_1  Healthcare  2022-06    7.82    9.11  30570  7408   966  13.04
# 30  Company_1  Healthcare  2022-07    6.96    7.28  29665  1112   -14  -1.26
# 31  Company_1  Healthcare  2022-08   12.41    6.71  29476  1050  -207 -19.71
# 32  Company_1  Healthcare  2022-09    8.70    5.62  30475  5040  -838 -16.63
# 33  Company_1  Healthcare  2022-10   11.06    9.43  32851  5908  -973 -16.47
# 34  Company_1  Healthcare  2022-11    9.78    4.02  26701  6419   235   3.66
# 35  Company_1  Healthcare  2022-12    5.04    4.17  27431  8771  -346  -3.94
# 36  Company_1  Healthcare  2023-01    5.17    8.39  28417  1948   220  11.29
# 37  Company_1  Healthcare  2023-02   14.29    8.33  31588  1158   -96  -8.29
# 38  Company_1  Healthcare  2023-03    5.91    3.23  31631  5332   848  15.90
# 39  Company_1  Healthcare  2023-04    7.30    3.01  30273  6598  1300  19.70
# 40  Company_1  Healthcare  2023-05    5.98    6.91  31826  8636  -267  -3.09
# 41  Company_1  Healthcare  2023-06    7.64    4.44  31231  5867  -165  -2.81
# 42  Company_1  Healthcare  2023-07    8.56    3.11  30311  6433 -1089 -16.93
# 43  Company_1  Healthcare  2023-08   13.29    8.53  30104  4823  -549 -11.38
# 44  Company_1  Healthcare  2023-09   12.65    7.75  28282  5551   979  17.64
# 45  Company_1  Healthcare  2023-10   11.77    8.31  27955  6502   929  14.29
# 46  Company_1  Healthcare  2023-11   13.27    9.32  32367  4123  -180  -4.37
# 47  Company_1  Healthcare  2023-12   12.00    8.87  28348  1051   -14  -1.33
# 48  Company_1  Healthcare  2024-01    5.99    8.81  26206  2383    69   2.90
# 49  Company_1  Healthcare  2024-02   10.57    8.92  29555  5306   595  11.21
# 50  Company_1  Healthcare  2024-03    9.31    3.61  28976  8867  -888 -10.01
# 51  Company_1  Healthcare  2024-04   13.63    8.76  28985  3990  -329  -8.25
# 52  Company_1  Healthcare  2024-05    6.83    3.98  30479  2234   209   9.36
# 53  Company_1  Healthcare  2024-06    9.31    5.65  30194  3482  -412 -11.83
# 54  Company_1  Healthcare  2024-07    5.62    6.75  33525  3776   110   2.91
# 55  Company_1  Healthcare  2024-08   11.19    5.88  26004  5619  -687 -12.23
# 56  Company_1  Healthcare  2024-09   10.47    8.88  29442  9410   712   7.57
# 57  Company_1  Healthcare  2024-10   11.82    5.21  30656  2356   331  14.05
#
#     당기순이익  ...  월평균급여액   월매출창출액  영업활동현금흐름/매출액  영업활동현금흐름  순현금흐름  매출채권  매입채무  \
# 0    -108  ...   271.2   9881.0          0.16      1589  -4968  3689  3237
# 1     339  ...   312.7   6409.7          0.14      1693  -3207  1976  3914
# 2    -135  ...   350.3  13090.7          0.15      2121    148  1508  2471
# 3     845  ...   263.8  19192.9          0.17      3547  -7583  3293  1211
# 4     430  ...   223.3  19615.9          0.20      1502 -11445  2587  3654
# 5     -10  ...   385.2  19706.9          0.14      4599  -6726  4290  3839
# 6      35  ...   306.2  10957.5          0.07      2856  -8867  3791  3349
# 7    -226  ...   240.3   5950.6          0.20      1549  -4537  2372  2317
# 8     117  ...   238.2  10959.3          0.17      2070  -6354  4718  3458
# 9    -111  ...   354.6  19633.1          0.12      2942  -7568  2007  1906
# 10     81  ...   280.4  14362.2          0.11      4099  -2372  2398  2298
# 11     18  ...   378.5   5771.4          0.12      4408  -8232  2950  3663
# 12    502  ...   269.9   5366.0          0.18      2457  -6779  1986  3421
# 13     34  ...   210.5  18423.8          0.18      2078 -10837  4069  2086
# 14     14  ...   230.8  19058.4          0.15      4692   -962  3941  1700
# 15    -54  ...   439.0  12222.8          0.07      3294  -3749  1183  3589
# 16    -81  ...   395.1  12189.2          0.14      4089  -2938  2241  2257
# 17    -22  ...   239.3  19547.3          0.12      1228  -8098  1083  2890
# 18     32  ...   264.7  14883.3          0.11      1252  -6921  1670   917
# 19   -384  ...   230.4  12288.1          0.09      2331  -4100  4483  3304
# 20    -12  ...   301.2  18582.9          0.17      2361  -8331  1488  1380
# 21     54  ...   248.5  16794.1          0.14      3277  -3331  2770  3462
# 22    -46  ...   266.2   7606.3          0.15      3746  -6649  1565  1478
# 23    411  ...   231.6   5533.6          0.13      2865  -6344  2927  1366
# 24   1355  ...   489.5  12325.9          0.07      2973  -5248  4322  1020
# 25    -68  ...   447.5  12473.8          0.06      1182  -9170  1375  2647
# 26    352  ...   433.0   5980.5          0.12      1977  -5813  2736  1084
# 27   -155  ...   248.5   8832.4          0.19      2063  -4856  4599   870
# 28    -48  ...   448.5  10028.1          0.08      4093  -1495  2488  2245
# 29   -357  ...   233.8  15555.3          0.13      2527  -1330  3995  2884
# 30      2  ...   284.2   8104.9          0.13      3844  -3024  1193  3689
# 31     45  ...   448.7  19868.9          0.17      4112   1475  3288  2441
# 32    -16  ...   342.2  11661.9          0.20      2600 -10268  4267  1016
# 33   -281  ...   308.7  15885.7          0.18      3981   1521  4920  2329
# 34    129  ...   413.0  15002.8          0.08       514 -12095  3561  1755
# 35     41  ...   413.9  14995.8          0.19      3125  -1456  4369  2557
# 36     74  ...   442.1   6803.1          0.09      2752  -2205  2731  2265
# 37    -48  ...   364.1   7704.6          0.12       506  -6458  2199  2869
# 38    319  ...   217.3  11665.5          0.09      2263  -8808  3636  1148
# 39      3  ...   418.8  19502.7          0.08      4560  -3262  4509  3918
# 40     28  ...   350.3  15592.9          0.13      1317  -8061  2484  3686
# 41     16  ...   344.9   9028.0          0.09      3715  -1021  4810  1526
# 42    437  ...   223.1  18667.5          0.10      3196  -5261  3495  2875
# 43   -152  ...   292.3  18706.8          0.19      4482  -3045  2533  2379
# 44    626  ...   431.9  19271.6          0.17      2764  -2733  1775  3548
# 45    349  ...   204.4   8108.6          0.16      3716  -7592  4526  3140
# 46     53  ...   480.1  17020.2          0.15      3984  -4127  4410  2533
# 47     -3  ...   440.8  19413.8          0.13      4513  -1218  4397  2099
# 48    -10  ...   412.0  14258.3          0.07      2097  -8798  1208   902
# 49    -63  ...   438.8   7626.8          0.15      4439   1508  2767  3950
# 50    140  ...   284.8  11278.7          0.09      3323  -6016  4001  1287
# 51    147  ...   252.0  12287.3          0.07      1365  -8378  2183  2783
# 52     67  ...   372.9  16428.3          0.17       704  -6933  1872   849
# 53    197  ...   474.5   8767.5          0.18      3208  -2037  4748  1798
# 54     -8  ...   369.8  16271.8          0.07      4903    778  4863  2064
# 55    260  ...   328.2   9954.3          0.13      1929  -2888  2038  1080
# 56    406  ...   238.2  17003.1          0.18      4183  -6836  1161  3648
# 57    261  ...   240.0  14485.9          0.07      3225  -8609  2232  3480
#
#     재고자산                                             상위_매출처  \
# 0   3901  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'A'...
# 1   5145  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'BB...
# 2   8160  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'AA...
# 3   8490  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'BB...
# 4   3173  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'A'...
# 5   7806  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'A+...
# 6   5675  [{'매출처_회사명': 'SalesPartner_6', '매출처_신용등급': 'AA...
# 7   4841  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'CC...
# 8   9720  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'CC...
# 9   3453  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'A'...
# 10  7000  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'A+...
# 11  8399  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'BB...
# 12  8395  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'BB...
# 13  5839  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 14  4021  [{'매출처_회사명': 'SalesPartner_6', '매출처_신용등급': 'A+...
# 15  9788  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'CC...
# 16  2093  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'AA...
# 17  4659  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 18  7891  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 19  6536  [{'매출처_회사명': 'SalesPartner_5', '매출처_신용등급': 'A+...
# 20  7449  [{'매출처_회사명': 'SalesPartner_8', '매출처_신용등급': 'AA...
# 21  7357  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 22  8550  [{'매출처_회사명': 'SalesPartner_5', '매출처_신용등급': 'BB...
# 23  5097  [{'매출처_회사명': 'SalesPartner_5', '매출처_신용등급': 'AA...
# 24  5394  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'CC...
# 25  9017  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'A'...
# 26  3765  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'AA...
# 27  7310  [{'매출처_회사명': 'SalesPartner_6', '매출처_신용등급': 'BB...
# 28  5179  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'BB...
# 29  6967  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 30  8818  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'B'...
# 31  4348  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'A+...
# 32  5099  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'A'...
# 33  6258  [{'매출처_회사명': 'SalesPartner_8', '매출처_신용등급': 'AA...
# 34  3923  [{'매출처_회사명': 'SalesPartner_5', '매출처_신용등급': 'AA...
# 35  3754  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'AA...
# 36  3671  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'A'...
# 37  9794  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'A+...
# 38  7092  [{'매출처_회사명': 'SalesPartner_4', '매출처_신용등급': 'AA...
# 39  2220  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'CC...
# 40  8454  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'A'...
# 41  9035  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'AA...
# 42  4139  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'BB...
# 43  4266  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 44  7416  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'B'...
# 45  7578  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'CC...
# 46  8066  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'A'...
# 47  2110  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'A+...
# 48  5387  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'A+...
# 49  5166  [{'매출처_회사명': 'SalesPartner_6', '매출처_신용등급': 'AA...
# 50  5667  [{'매출처_회사명': 'SalesPartner_5', '매출처_신용등급': 'BB...
# 51  6797  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'CC...
# 52  6651  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'A+...
# 53  3998  [{'매출처_회사명': 'SalesPartner_7', '매출처_신용등급': 'BB...
# 54  7827  [{'매출처_회사명': 'SalesPartner_2', '매출처_신용등급': 'BB...
# 55  2719  [{'매출처_회사명': 'SalesPartner_3', '매출처_신용등급': 'CC...
# 56  9936  [{'매출처_회사명': 'SalesPartner_5', '매출처_신용등급': 'AA...
# 57  6916  [{'매출처_회사명': 'SalesPartner_1', '매출처_신용등급': 'AA...
#
#                                                상위_매입처
# 0   [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 1   [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 2   [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 3   [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 4   [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...
# 5   [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 6   [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 7   [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 8   [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 9   [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 10  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 11  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 12  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 13  [{'매입처_회사명': 'PurchasePartner_5', '매입처_신용등급': ...
# 14  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 15  [{'매입처_회사명': 'PurchasePartner_5', '매입처_신용등급': ...
# 16  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 17  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 18  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 19  [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...
# 20  [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 21  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 22  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 23  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 24  [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...
# 25  [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 26  [{'매입처_회사명': 'PurchasePartner_5', '매입처_신용등급': ...
# 27  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 28  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 29  [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 30  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 31  [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...
# 32  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 33  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 34  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 35  [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 36  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 37  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 38  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 39  [{'매입처_회사명': 'PurchasePartner_5', '매입처_신용등급': ...
# 40  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 41  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 42  [{'매입처_회사명': 'PurchasePartner_2', '매입처_신용등급': ...
# 43  [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 44  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 45  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 46  [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 47  [{'매입처_회사명': 'PurchasePartner_8', '매입처_신용등급': ...
# 48  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 49  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 50  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
# 51  [{'매입처_회사명': 'PurchasePartner_1', '매입처_신용등급': ...
# 52  [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...
# 53  [{'매입처_회사명': 'PurchasePartner_6', '매입처_신용등급': ...
# 54  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 55  [{'매입처_회사명': 'PurchasePartner_4', '매입처_신용등급': ...
# 56  [{'매입처_회사명': 'PurchasePartner_3', '매입처_신용등급': ...
# 57  [{'매입처_회사명': 'PurchasePartner_7', '매입처_신용등급': ...
#
# [58 rows x 28 columns]

# %% [markdown]
# ## 3. 데이터전처리
#
# - 현황 : 성장성, 수익성 구현
# - 전처리 함수
#   - preprocess_growth_data : '총자산', '매출액' 등 성장성 관련 Data를 Dict 형태로 변경
#   - preprocess_profitability_data : '영업이익', '당기순이익' 등 수익성 관련 Data를 Dict 형태로 변경

# %% [markdown]
# ### 성장성 (Growth) 전처리

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Dict, Any
import logging

# 재현성을 위한 Random seed 설정
np.random.seed(42)

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# 접근 시점 정의
ACCESS_TIME = '2024-09-01'
access_datetime = pd.to_datetime(ACCESS_TIME)

class DataValidationError(Exception):
    """데이터 검증 관련 커스텀 예외"""
    pass

class GrowthMetricsCalculator:
    """성장성 지표 계산을 위한 메인 클래스"""

    REQUIRED_COLUMNS = ['기업명', '날짜', '업종', '총자산', '매출액']
    ASSET_COL, REVENUE_COL = '총자산', '매출액'
    COMPANY_COL, DATE_COL, INDUSTRY_COL = '기업명', '날짜', '업종'

    def __init__(self, df_company_info: pd.DataFrame, target_company_name: str, n_years: int = 3):
        self.df = self._validate_input_data(df_company_info)
        self.target_company_name = target_company_name
        self.n_years = n_years
        self.growth_data = {
            'annual_revenue': {},
            'annual_assets': {},
            'monthly_revenue': {},
            'monthly_growth': {}
        }

    def _validate_input_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """필수 컬럼 및 데이터 유효성 검증 후 데이터 반환"""
        if not all(col in df.columns for col in self.REQUIRED_COLUMNS):
            missing_cols = set(self.REQUIRED_COLUMNS) - set(df.columns)
            raise DataValidationError(f"필수 컬럼 누락: {missing_cols}")
        if df[self.COMPANY_COL].isnull().all():
            raise DataValidationError(f"회사를 찾을 수 없음")
        for col in [self.ASSET_COL, self.REVENUE_COL]:
            if not pd.to_numeric(df[col], errors='coerce').notnull().all():
                raise DataValidationError(f"숫자가 아닌 값이 포함됨: {col}")
        logger.info("데이터 검증 완료")
        return df[self.REQUIRED_COLUMNS].copy()

    def _prepare_data(self):
        """데이터 전처리 및 필요한 필드 추가"""
        self.df['date'] = pd.to_datetime(self.df[self.DATE_COL])
        self.df['year'] = self.df['date'].dt.year
        self.df['month'] = self.df['date'].dt.month
        self.df = self.df.fillna({self.ASSET_COL: 0, self.REVENUE_COL: 0})
        self.df_company = self.df[self.df[self.COMPANY_COL] == self.target_company_name].reset_index(drop=True)
        if self.df_company.empty:
            raise DataValidationError(f"회사 데이터가 없음: {self.target_company_name}")
        self.target_industry = self.df_company[self.INDUSTRY_COL].iloc[0]
        self.df_industry = self.df[self.df[self.INDUSTRY_COL] == self.target_industry].reset_index(drop=True)
        self.latest_date = access_datetime - pd.DateOffset(months=1)
        logger.info(f"데이터 준비 완료 - 기준일자: {self.latest_date.strftime('%Y-%m-%d')}")

    def _calculate_growth_rate(self, current: float, previous: float, threshold: float = 0.0001) -> float:
        """성장률 계산"""
        if abs(previous) < threshold:
            logger.warning(f"이전 값이 임계값보다 작음 (previous: {previous})")
            return 0
        return round((current - previous) / previous * 100, 2)

    def _process_annual_data(self):
        """과거 연도 및 연말 예상 연도 데이터 계산 및 저장"""
        for year_offset in range(1, self.n_years + 1):
            target_year = self.latest_date.year - year_offset
            self._calculate_annual_metrics(target_year, estimate=False)
        self._calculate_annual_metrics(self.latest_date.year, estimate=True)  # 연말 예상 데이터

    def _calculate_annual_metrics(self, year: int, estimate: bool = False):
        """연간 또는 연말 예상 데이터 계산"""
        if estimate:
            # 2024년 9월까지 누적 매출액을 기반으로 연환산 수행
            current_data = self.df_company[(self.df_company['year'] == year) & (self.df_company['month'] <= self.latest_date.month)]
            current_revenue = int((current_data[self.REVENUE_COL].sum() / self.latest_date.month) * 12)
        else:
            # 기존 연도는 그대로 누적합 사용
            current_data = self.df_company[self.df_company['year'] == year]
            current_revenue = int(current_data[self.REVENUE_COL].sum())
        
        prev_data = self.df_company[self.df_company['year'] == year - 1]
        prev_revenue = int(prev_data[self.REVENUE_COL].sum() if not prev_data.empty else 0)

        # 자산 데이터 처리 (연환산 불필요)
        current_assets = int(current_data[self.ASSET_COL].iloc[-1] if not current_data.empty else 0)
        prev_assets = int(prev_data[self.ASSET_COL].iloc[-1] if not prev_data.empty else 0)

        # 산업 평균 계산
        current_industry_data = self.df_industry[self.df_industry['year'] == year]
        prev_industry_data = self.df_industry[self.df_industry['year'] == year - 1]

        industry_revenue = int(current_industry_data[self.REVENUE_COL].sum())
        prev_industry_revenue = int(prev_industry_data[self.REVENUE_COL].sum() if not prev_industry_data.empty else 0)
        industry_assets = int(current_industry_data[self.ASSET_COL].mean() if not current_industry_data.empty else 0)
        prev_industry_assets = int(prev_industry_data[self.ASSET_COL].mean() if not prev_industry_data.empty else 0)

        key = f"{year}년(E)" if estimate else f"{year}년"
        self.growth_data['annual_revenue'][key] = {
            '매출액': current_revenue,
            '매출액증가율': self._calculate_growth_rate(current_revenue, prev_revenue),
            '업종평균 매출액증가율': self._calculate_growth_rate(industry_revenue, prev_industry_revenue),
        }
        self.growth_data['annual_assets'][key] = {
            '총자산': current_assets,
            '총자산증가율': self._calculate_growth_rate(current_assets, prev_assets),
            '업종평균 총자산증가율': self._calculate_growth_rate(industry_assets, prev_industry_assets)
        }

    def _process_monthly_data(self):
        """최근 12개월 월별 데이터 계산 및 저장"""
        # 2023-08부터 시작하는 최근 12개월 생성
        past_12_months = pd.date_range(end=self.latest_date + pd.DateOffset(months=1), periods=12, freq='ME')
        cumulative_data = {'current': {'revenue': 0}, 'previous': {'revenue': 0}}

        for idx, date in enumerate(past_12_months):
            month_str = date.strftime('%Y-%m')
            current_month = self.df_company[self.df_company['date'].dt.strftime('%Y-%m') == month_str]
            prev_month = self.df_company[self.df_company['date'].dt.strftime('%Y-%m') == (date - pd.DateOffset(years=1)).strftime('%Y-%m')]

            current_revenue = int(current_month[self.REVENUE_COL].sum())
            prev_revenue = int(prev_month[self.REVENUE_COL].sum() if not prev_month.empty else 0)

            cumulative_data['current']['revenue'] += current_revenue
            cumulative_data['previous']['revenue'] += prev_revenue

            self.growth_data['monthly_revenue'][month_str] = {
                '당월매출액': current_revenue,
                '전년동월매출액': prev_revenue
            }
            self.growth_data['monthly_growth'][month_str] = {
                '매출액증가율': self._calculate_growth_rate(current_revenue, prev_revenue),
                '누적매출액증가율': self._calculate_growth_rate(
                    cumulative_data['current']['revenue'],
                    cumulative_data['previous']['revenue']
                )
            }
            logger.debug(f"{month_str} 월별 데이터 처리 완료")


    def calculate_growth_metrics(self) -> Dict[str, pd.DataFrame]:
        """성장성 지표 계산 실행"""
        self._prepare_data()
        self._process_annual_data()
        self._process_monthly_data()

        # DataFrames 생성 및 날짜 순 정렬 (Transpose를 한 번만 사용)
        annual_revenue_df = pd.DataFrame(self.growth_data['annual_revenue']).sort_index(axis=1)
        annual_assets_df = pd.DataFrame(self.growth_data['annual_assets']).sort_index(axis=1)
        monthly_revenue_df = pd.DataFrame(self.growth_data['monthly_revenue']).sort_index(axis=1)
        monthly_growth_df = pd.DataFrame(self.growth_data['monthly_growth']).sort_index(axis=1)

        return {
            'latest_year_month': self.latest_date.strftime('%Y-%m'),
            'annual_revenue': annual_revenue_df,
            'annual_assets': annual_assets_df,
            'monthly_revenue': monthly_revenue_df,
            'monthly_growth': monthly_growth_df
        }


def preprocess_growth_data(df_company_info: pd.DataFrame, target_company_name: str) -> Dict[str, Any]:
    """성장성 지표 데이터를 전처리하여 JSON 형식으로 변환"""
    calculator = GrowthMetricsCalculator(df_company_info, target_company_name)
    return calculator.calculate_growth_metrics()



growth_data = preprocess_growth_data(df_company_info, 'Company_2')
print('#'*10, 'last_year_month', '#'*10)
pprint(growth_data['latest_year_month'])
print()

print('#'*10, 'annual_revenue', '#'*10)
pprint(pd.DataFrame(growth_data['annual_revenue']))
print()

print('#'*10, 'annual_assets', '#'*10)
pprint(pd.DataFrame(growth_data['annual_assets']))
print()

print('#'*10, 'monthly_revenue', '#'*10)
pprint(pd.DataFrame(growth_data['monthly_revenue']))
print()

print('#'*10, 'monthly_growth', '#'*10)
pprint(pd.DataFrame(growth_data['monthly_growth']))
# Out:
# 2024-11-26 12:52:06,890 - INFO - 데이터 검증 완료
# 2024-11-26 12:52:06,904 - INFO - 데이터 준비 완료 - 기준일자: 2024-08-01
# ########## last_year_month ##########
# '2024-08'
#
# ########## annual_revenue ##########
#                 2021년     2022년     2023년  2024년(E)
# 매출액          64201.00  53209.00  61425.00  62346.00
# 매출액증가율           8.85    -17.12     15.44      1.50
# 업종평균 매출액증가율     -6.56      7.88      1.79    -15.36
#
# ########## annual_assets ##########
#                 2021년     2022년     2023년  2024년(E)
# 총자산          27971.00  31661.00  31157.00  30831.00
# 총자산증가율          -9.19     13.19     -1.59     -1.05
# 업종평균 총자산증가율      0.58     -0.84      0.10     -0.17
#
# ########## monthly_revenue ##########
#          2023-09  2023-10  2023-11  2023-12  2024-01  2024-02  2024-03  \
# 당월매출액       3720     1955     3427     2741     2126     7598     6610
# 전년동월매출액     6053     7321     1552     2910     6817     7878     2617
#
#          2024-04  2024-05  2024-06  2024-07  2024-08
# 당월매출액       4062     7746     3056     5021     5345
# 전년동월매출액     1268     9760     9048     3789     8405
#
# ########## monthly_growth ##########
#           2023-09  2023-10  2023-11  2023-12  2024-01  2024-02  2024-03  \
# 매출액증가율     -38.54   -73.30   120.81    -5.81   -68.81    -3.55   152.58
# 누적매출액증가율   -38.54   -57.57   -39.02   -33.60   -43.34   -33.70   -19.83
#
#           2024-04  2024-05  2024-06  2024-07  2024-08
# 매출액증가율     220.35   -20.64   -66.22    32.52   -36.41
# 누적매출액증가율   -11.47   -13.41   -22.06   -18.56   -20.78

# %%
import json
import pandas as pd

# DataFrame을 dict로 변환하는 함수
def convert_df_to_dict(data):
    if isinstance(data, dict):
        return {k: convert_df_to_dict(v) for k, v in data.items()}
    elif isinstance(data, pd.DataFrame):
        return data.to_dict()
    else:
        return data

# growth_data의 DataFrame을 dict로 변환
growth_data_converted = convert_df_to_dict(growth_data)

# JSON 파일로 저장
with open('growth_data.json', 'w', encoding='utf-8') as f:
    json.dump(growth_data_converted, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Profitability (수익성) 전처리

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Dict, Any
import logging

# 재현성을 위한 Random seed 설정
np.random.seed(42)

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# 접근 시점 정의
ACCESS_TIME = '2024-11-01'
access_datetime = pd.to_datetime(ACCESS_TIME)

class DataValidationError(Exception):
    """데이터 검증 관련 커스텀 예외"""
    pass

class ProfitabilityMetricsCalculator:
    """수익성 지표 계산을 위한 메인 클래스"""

    REQUIRED_COLUMNS = ['기업명', '날짜', '업종', '영업이익', '당기순이익', '매출액']
    OPERATING_PROFIT_COL, NET_PROFIT_COL, REVENUE_COL = '영업이익', '당기순이익', '매출액'
    COMPANY_COL, DATE_COL, INDUSTRY_COL = '기업명', '날짜', '업종'

    def __init__(self, df_company_info: pd.DataFrame, target_company_name: str, n_years: int = 3):
        self.df = self._validate_input_data(df_company_info)
        self.target_company_name = target_company_name
        self.n_years = n_years
        self.profitability_data = {
            'annual_profit': {},
            'annual_margins': {},
            'monthly_profit': {},
            'monthly_margins': {}
        }

    def _validate_input_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """필수 컬럼 및 데이터 유효성 검증 후 데이터 반환"""
        if not all(col in df.columns for col in self.REQUIRED_COLUMNS):
            missing_cols = set(self.REQUIRED_COLUMNS) - set(df.columns)
            raise DataValidationError(f"필수 컬럼 누락: {missing_cols}")
        if df[self.COMPANY_COL].isnull().all():
            raise DataValidationError(f"회사를 찾을 수 없음")
        for col in [self.OPERATING_PROFIT_COL, self.NET_PROFIT_COL, self.REVENUE_COL]:
            if not pd.to_numeric(df[col], errors='coerce').notnull().all():
                raise DataValidationError(f"숫자가 아닌 값이 포함됨: {col}")
        logger.info("데이터 검증 완료")
        return df[self.REQUIRED_COLUMNS].copy()

    def _prepare_data(self):
        """데이터 전처리 및 필요한 필드 추가"""
        self.df['date'] = pd.to_datetime(self.df[self.DATE_COL])
        self.df['year'] = self.df['date'].dt.year
        self.df['month'] = self.df['date'].dt.month
        self.df = self.df.fillna({self.OPERATING_PROFIT_COL: 0, self.NET_PROFIT_COL: 0, self.REVENUE_COL: 0})
        self.df_company = self.df[self.df[self.COMPANY_COL] == self.target_company_name].reset_index(drop=True)
        if self.df_company.empty:
            raise DataValidationError(f"회사 데이터가 없음: {self.target_company_name}")
        self.target_industry = self.df_company[self.INDUSTRY_COL].iloc[0]
        self.df_industry = self.df[self.df[self.INDUSTRY_COL] == self.target_industry].reset_index(drop=True)
        self.latest_date = access_datetime - pd.DateOffset(months=1)
        self.latest_month = self.latest_date.month
        logger.info(f"데이터 준비 완료 - 기준일자: {self.latest_date.strftime('%Y-%m-%d')}")

    def _calculate_margin_rate(self, profit: float, revenue: float, threshold: float = 0.0001) -> float:
        """이익률 계산"""
        if abs(revenue) < threshold:
            logger.warning(f"매출액이 임계값보다 작음 (revenue: {revenue})")
            return 0
        return round((profit / revenue * 100), 2)

    def _process_annual_data(self):
        """과거 연도 및 연말 예상 연도 데이터 계산 및 저장"""
        for year_offset in range(1, self.n_years + 1):
            target_year = self.latest_date.year - year_offset
            self._calculate_annual_metrics(target_year, estimate=False)
        self._calculate_annual_metrics(self.latest_date.year, estimate=True)  # 연말 예상 데이터

    def _calculate_annual_metrics(self, year: int, estimate: bool = False):
        """연간 또는 연말 예상 데이터 계산"""
        if estimate:
            current_data = self.df_company[(self.df_company['year'] == year) & (self.df_company['month'] <= self.latest_month)]
            annualized_metrics = self._calculate_annualized_metrics(current_data, is_industry=False)
            industry_metrics = self._calculate_annualized_metrics(self.df_industry[self.df_industry['year'] == year], is_industry=True)
        else:
            current_data = self.df_company[self.df_company['year'] == year]
            prev_data = self.df_company[self.df_company['year'] == year - 1]
            industry_data = self.df_industry[self.df_industry['year'] == year]
            annualized_metrics = self._calculate_metrics(current_data, prev_data)
            industry_metrics = self._calculate_metrics(industry_data, None)

        key = f"{year}년(E)" if estimate else f"{year}년"
        self.profitability_data['annual_profit'][key] = {
            '영업이익': annualized_metrics['operating_profit'],
            '당기순이익': annualized_metrics['net_profit']
        }
        self.profitability_data['annual_margins'][key] = {
            '영업이익률': annualized_metrics['operating_profit_margin'],
            '당기순이익률': annualized_metrics['net_profit_margin'],
            '업종평균 영업이익률': industry_metrics['operating_profit_margin'],
            '업종평균 당기순이익률': industry_metrics['net_profit_margin']
        }

    def _calculate_annualized_metrics(self, current_data: pd.DataFrame, is_industry: bool = False) -> Dict[str, float]:
        """연환산 지표 계산"""
        monthly_op = current_data[self.OPERATING_PROFIT_COL].sum()
        monthly_np = current_data[self.NET_PROFIT_COL].sum()
        monthly_rev = current_data[self.REVENUE_COL].sum()

        # 연환산 계산
        annualized_op = (monthly_op / self.latest_month) * 12
        annualized_np = (monthly_np / self.latest_month) * 12
        annualized_rev = (monthly_rev / self.latest_month) * 12

        return {
            'operating_profit': int(round(annualized_op)),
            'net_profit': int(round(annualized_np)),
            'operating_profit_margin': self._calculate_margin_rate(annualized_op, annualized_rev),
            'net_profit_margin': self._calculate_margin_rate(annualized_np, annualized_rev)
        }

    def _calculate_metrics(self, current_data: pd.DataFrame, prev_data: pd.DataFrame = None) -> Dict[str, float]:
        """연간 수익성 지표 계산"""
        current_op = current_data[self.OPERATING_PROFIT_COL].sum()
        current_np = current_data[self.NET_PROFIT_COL].sum()
        current_rev = current_data[self.REVENUE_COL].sum()

        return {
            'operating_profit': int(round(current_op)),
            'net_profit': int(round(current_np)),
            'operating_profit_margin': self._calculate_margin_rate(current_op, current_rev),
            'net_profit_margin': self._calculate_margin_rate(current_np, current_rev)
        }

    def _process_monthly_data(self):
        """최근 12개월 월별 데이터 계산 및 저장"""
        past_12_months = pd.date_range(end=self.latest_date + pd.DateOffset(months=1), periods=12, freq='ME')
        cumulative_data = {'current': {'operating_profit': 0, 'net_profit': 0, 'revenue': 0}}

        for idx, date in enumerate(past_12_months):
            month_str = date.strftime('%Y-%m')
            current_month = self.df_company[self.df_company['date'].dt.strftime('%Y-%m') == month_str]
            prev_month = self.df_company[self.df_company['date'].dt.strftime('%Y-%m') == (date - pd.DateOffset(years=1)).strftime('%Y-%m')]

            current_op = int(current_month[self.OPERATING_PROFIT_COL].sum())
            current_np = int(current_month[self.NET_PROFIT_COL].sum())
            current_rev = int(current_month[self.REVENUE_COL].sum())
            prev_op = int(prev_month[self.OPERATING_PROFIT_COL].sum()) if not prev_month.empty else 0
            prev_np = int(prev_month[self.NET_PROFIT_COL].sum()) if not prev_month.empty else 0

            cumulative_data['current']['operating_profit'] += current_op
            cumulative_data['current']['net_profit'] += current_np
            cumulative_data['current']['revenue'] += current_rev

            self.profitability_data['monthly_profit'][month_str] = {
                '당월영업이익': current_op,
                '전년동월영업이익': prev_op,
                '당월당기순이익': current_np,
                '전년동월당기순이익': prev_np
            }
            self.profitability_data['monthly_margins'][month_str] = {
                '영업이익률': self._calculate_margin_rate(current_op, current_rev),
                '누적영업이익률': self._calculate_margin_rate(cumulative_data['current']['operating_profit'], cumulative_data['current']['revenue']),
                '당기순이익률': self._calculate_margin_rate(current_np, current_rev),
                '누적순이익률': self._calculate_margin_rate(cumulative_data['current']['net_profit'], cumulative_data['current']['revenue'])
            }

    def calculate_profitability_metrics(self) -> Dict[str, pd.DataFrame]:
        """수익성 지표 계산 실행"""
        self._prepare_data()
        self._process_annual_data()
        self._process_monthly_data()

        # DataFrames 생성 및 날짜 순 정렬
        annual_profit_df = pd.DataFrame(self.profitability_data['annual_profit']).sort_index(axis=1)
        annual_margins_df = pd.DataFrame(self.profitability_data['annual_margins']).sort_index(axis=1)
        monthly_profit_df = pd.DataFrame(self.profitability_data['monthly_profit']).sort_index(axis=1)
        monthly_margins_df = pd.DataFrame(self.profitability_data['monthly_margins']).sort_index(axis=1)

        return {
            'latest_year_month': self.latest_date.strftime('%Y-%m'),
            'annual_profit': annual_profit_df,
            'annual_margins': annual_margins_df,
            'monthly_profit': monthly_profit_df,
            'monthly_margins': monthly_margins_df
        }

def preprocess_profitability_data(df_company_info: pd.DataFrame, target_company_name: str) -> Dict[str, Any]:
    """수익성 지표 데이터를 전처리하여 JSON 형식으로 변환"""
    calculator = ProfitabilityMetricsCalculator(df_company_info, target_company_name)
    return calculator.calculate_profitability_metrics()



profitability_data = preprocess_profitability_data(df_company_info, 'Company_1')

print('#'*10, 'last_year_month', '#'*10)
pprint(profitability_data['latest_year_month'])
print()

print('#'*10, 'annual_revenue', '#'*10)
pprint(pd.DataFrame(profitability_data['annual_profit']))
print()

print('#'*10, 'annual_assets', '#'*10)
pprint(pd.DataFrame(profitability_data['annual_margins']))
print()

print('#'*10, 'monthly_revenue', '#'*10)
pprint(pd.DataFrame(profitability_data['monthly_profit']))
print()

print('#'*10, 'monthly_growth', '#'*10)
pprint(pd.DataFrame(profitability_data['monthly_margins']))
# Out:
# 2024-11-26 12:52:16,311 - INFO - 데이터 검증 완료
# 2024-11-26 12:52:16,325 - INFO - 데이터 준비 완료 - 기준일자: 2024-10-01
# ########## last_year_month ##########
# '2024-10'
#
# ########## annual_revenue ##########
#        2021년  2022년  2023년  2024년(E)
# 영업이익   -1536   1119   1916      -348
# 당기순이익    448    999   1702      1676
#
# ########## annual_assets ##########
#              2021년  2022년  2023년  2024년(E)
# 영업이익률        -2.57   1.72   3.30     -0.61
# 당기순이익률        0.75   1.53   2.93      2.95
# 업종평균 영업이익률   -0.48  -0.47  -0.27     -1.05
# 업종평균 당기순이익률   0.01   0.42  -0.37     -0.17
#
# ########## monthly_revenue ##########
#            2023-11  2023-12  2024-01  2024-02  2024-03  2024-04  2024-05  \
# 당월영업이익        -180      -14       69      595     -888     -329      209
# 전년동월영업이익       235     -346      220      -96      848     1300     -267
# 당월당기순이익         53       -3      -10      -63      140      147       67
# 전년동월당기순이익      129       41       74      -48      319        3       28
#
#            2024-06  2024-07  2024-08  2024-09  2024-10
# 당월영업이익        -412      110     -687      712      331
# 전년동월영업이익      -165    -1089     -549      979      929
# 당월당기순이익        197       -8      260      406      261
# 전년동월당기순이익       16      437     -152      626      349
#
# ########## monthly_growth ##########
#          2023-11  2023-12  2024-01  2024-02  2024-03  2024-04  2024-05  \
# 영업이익률      -4.37    -1.33     2.90    11.21   -10.01    -8.25     9.36
# 누적영업이익률    -4.37    -3.75    -1.65     3.65    -1.92    -2.90    -1.92
# 당기순이익률      1.29    -0.29    -0.42    -1.19     1.58     3.68     3.00
# 누적순이익률      1.29     0.97     0.53    -0.18     0.54     1.03     1.18
#
#          2024-06  2024-07  2024-08  2024-09  2024-10
# 영업이익률     -11.83     2.91   -12.23     7.57    14.05
# 누적영업이익률    -3.02    -2.39    -3.74    -1.62    -0.92
# 당기순이익률      5.66    -0.21     4.63     4.31    11.08
# 누적순이익률      1.68     1.48     1.91     2.36     2.75

# %%
import pandas as pd
from typing import Dict, Any, List
from datetime import datetime
import os
import logging
from pprint import pprint

ACCESS_TIME = '2024-09-01'
ACCESS_DATE = pd.to_datetime(ACCESS_TIME)


class PartnerStabilityMetricsCalculator:
    """거래처 안정성 지표 계산 클래스"""
    
    REQUIRED_COLUMNS = ['기업명', '날짜', '상위_매출처', '상위_매입처']
    
    def __init__(self, df: pd.DataFrame, company: str):
        """
        Args:
            df: 회사 데이터가 포함된 DataFrame
            company: 대상 회사명
        """
        self.df = df.copy()
        self._validate_input_data()
        self.df.loc[:, '날짜'] = pd.to_datetime(self.df['날짜'])
        self.df_target = self.df[self.df['기업명'] == company]
        self.latest_date = (ACCESS_DATE - pd.DateOffset(months=1)).strftime('%Y-%m')
        
    def _validate_input_data(self) -> None:
        """입력 데이터 검증"""
        missing_cols = set(self.REQUIRED_COLUMNS) - set(self.df.columns)
        if missing_cols:
            raise ValueError(f"필수 컬럼 누락: {missing_cols}")

    def _process_partner_data(self, partner_type: str) -> Dict[str, Any]:
        """거래처 데이터 처리"""
        start_date = pd.to_datetime(self.latest_date) - pd.DateOffset(months=11)
        
        # 기간 필터링
        # period_data = self.df_target[
        #     (self.df_target['날짜'] >= start_date) & 
        #     (self.df_target['날짜'] <= pd.to_datetime(self.latest_date))
        # ]
        
        # period_data = self.df_target[
        # (self.df_target['날짜'].dt.strftime('%Y-%m') >= start_date.strftime('%Y-%m')) & 
        # (self.df_target['날짜'].dt.strftime('%Y-%m') <= self.latest_date)
        # ]
        
        period_data = self.df_target[
        (self.df_target['날짜'] >= start_date) & 
        (self.df_target['날짜'] <= pd.to_datetime(self.latest_date) + pd.offsets.MonthEnd(1))
        ]
        
        # 거래처 데이터 추출
        partner_key = f'상위_{partner_type}처'
        partner_data = []
        for _, row in period_data.iterrows():
            for partner in row[partner_key]:
                partner_dict = partner.copy()
                partner_dict['날짜'] = row['날짜']
                partner_data.append(partner_dict)
                
        if not partner_data:
            return {}

        # 컬럼명 설정
        company_col = f'{partner_type}처_회사명'
        grade_col = f'{partner_type}처_신용등급'
        amount_col = f'{partner_type}처_{partner_type}금액'
        term_col = f'{partner_type}처_회수기일' if partner_type == '매출' else f'{partner_type}처_지급기일'

        # 데이터프레임 생성
        partner_df = pd.DataFrame(partner_data)
        
        # Top 5 거래처 선정
        total_by_company = partner_df.groupby(company_col)[amount_col].sum()
        top_5_companies = total_by_company.nlargest(5).index.tolist()
        
        # 연간 데이터 생성
        annual_data = []
        total_amount = total_by_company.sum()
        top_5_amount = total_by_company[top_5_companies].sum()
        
        for company in top_5_companies:
            company_data = partner_df[partner_df[company_col] == company]
            annual_amount = total_by_company[company]
            
            annual_data.append({
                '회사명': company,
                '신용등급': company_data[grade_col].iloc[0],
                f'연간_{partner_type}금액': annual_amount,
                '거래비율': round((annual_amount / total_amount * 100), 2)
            })
        
        # 합계 정보 추가
        annual_data.extend([
            {
                '회사명': '상위 5개 거래처 합계',
                f'연간_{partner_type}금액': top_5_amount,
                '거래비율': round((top_5_amount / total_amount * 100), 2)
            },
            {
                '회사명': '기타 거래처 합계',
                f'연간_{partner_type}금액': total_amount - top_5_amount,
                '거래비율': round(((total_amount - top_5_amount) / total_amount * 100), 2)
            }
        ])
        
        # 월별 데이터 생성
        monthly_data = {}
        for company in top_5_companies:
            company_data = partner_df[partner_df[company_col] == company]
            company_monthly = []
            
            # 전체 기간의 합계 계산
            total_term = company_data[term_col].sum()
            annual_amount = total_by_company[company]
            
            # 최근 12개월 데이터 추가
            # for month in pd.date_range(start=start_date, end=pd.to_datetime(self.latest_date), freq='ME'):
            #     month_data = company_data[
            #         company_data['날짜'].dt.to_period('M') == month.to_period('M')
            #     ]
            
            for month in pd.date_range(start=start_date, end=pd.to_datetime(self.latest_date) + pd.offsets.MonthEnd(1), freq='ME'):
                month_data = company_data[
                company_data['날짜'].dt.to_period('M') == month.to_period('M')
                ]
                
                if not month_data.empty:
                    amount = month_data[amount_col].sum()
                    company_monthly.append({
                        '날짜': month.strftime('%Y-%m'),
                        f'{partner_type}금액': amount
                    })

            # 평균 데이터 추가 (extend 사용)
            company_monthly.extend([
                {
                    '날짜': f'평균{partner_type}금액',
                    f'{partner_type}금액': round(annual_amount / 12, 2)
                },
                {
                    '날짜': f'평균{"회수" if partner_type=="매출" else "지급"}기일',
                    f'{partner_type}금액': round(total_term / 12, 2)
                }
            ])
            
            monthly_data[company] = company_monthly

        return {
            'annual_data': annual_data,
            'monthly_data': monthly_data
        }

    def calculate_stability_metrics(self) -> Dict[str, Any]:
        """안정성 지표 계산 실행"""
        sales_data = self._process_partner_data('매출')
        purchase_data = self._process_partner_data('매입')
        
        return {
            'latest_year_month': self.latest_date,
            'annual_top5_sales': sales_data.get('annual_data', []),
            'monthly_top5_sales': sales_data.get('monthly_data', {}),
            'annual_top5_purchase': purchase_data.get('annual_data', []),
            'monthly_top5_purchase': purchase_data.get('monthly_data', {})
        }

def preprocess_partner_stability_data(df: pd.DataFrame, company: str) -> Dict[str, Any]:
    """안정성 지표 전처리 함수"""
    calculator = PartnerStabilityMetricsCalculator(df, company)
    return calculator.calculate_stability_metrics()

# 'Company_1'에 대한 안정성 지표를 계산
company_1_stability = preprocess_partner_stability_data(df_company_info, 'Company_1')
pprint(company_1_stability)
# Out:
# {'annual_top5_purchase': [{'거래비율': 17.76,
#                            '신용등급': 'A+',
#                            '연간_매입금액': 63224,
#                            '회사명': 'PurchasePartner_3'},
#                           {'거래비율': 15.81,
#                            '신용등급': 'B',
#                            '연간_매입금액': 56265,
#                            '회사명': 'PurchasePartner_4'},
#                           {'거래비율': 14.43,
#                            '신용등급': 'BB',
#                            '연간_매입금액': 51371,
#                            '회사명': 'PurchasePartner_5'},
#                           {'거래비율': 13.74,
#                            '신용등급': 'CCC-',
#                            '연간_매입금액': 48897,
#                            '회사명': 'PurchasePartner_6'},
#                           {'거래비율': 10.58,
#                            '신용등급': 'BBB',
#                            '연간_매입금액': 37643,
#                            '회사명': 'PurchasePartner_1'},
#                           {'거래비율': 72.32,
#                            '연간_매입금액': 257400,
#                            '회사명': '상위 5개 거래처 합계'},
#                           {'거래비율': 27.68,
#                            '연간_매입금액': 98528,
#                            '회사명': '기타 거래처 합계'}],
#  'annual_top5_sales': [{'거래비율': 20.55,
#                         '신용등급': 'AA',
#                         '연간_매출금액': 63276,
#                         '회사명': 'SalesPartner_7'},
#                        {'거래비율': 18.1,
#                         '신용등급': 'B',
#                         '연간_매출금액': 55743,
#                         '회사명': 'SalesPartner_3'},
#                        {'거래비율': 13.39,
#                         '신용등급': 'AAA',
#                         '연간_매출금액': 41240,
#                         '회사명': 'SalesPartner_6'},
#                        {'거래비율': 12.97,
#                         '신용등급': 'AA+',
#                         '연간_매출금액': 39941,
#                         '회사명': 'SalesPartner_5'},
#                        {'거래비율': 10.82,
#                         '신용등급': 'BBB+',
#                         '연간_매출금액': 33335,
#                         '회사명': 'SalesPartner_4'},
#                        {'거래비율': 75.83,
#                         '연간_매출금액': 233535,
#                         '회사명': '상위 5개 거래처 합계'},
#                        {'거래비율': 24.17, '연간_매출금액': 74420, '회사명': '기타 거래처 합계'}],
#  'latest_year_month': '2024-08',
#  'monthly_top5_purchase': {'PurchasePartner_1': [{'날짜': '2023-09',
#                                                   '매입금액': 4951},
#                                                  {'날짜': '2023-10',
#                                                   '매입금액': 4359},
#                                                  {'날짜': '2023-12',
#                                                   '매입금액': 6393},
#                                                  {'날짜': '2024-01',
#                                                   '매입금액': 9778},
#                                                  {'날짜': '2024-04',
#                                                   '매입금액': 3655},
#                                                  {'날짜': '2024-05',
#                                                   '매입금액': 1466},
#                                                  {'날짜': '2024-08',
#                                                   '매입금액': 7041},
#                                                  {'날짜': '평균매입금액',
#                                                   '매입금액': 3136.92},
#                                                  {'날짜': '평균지급기일',
#                                                   '매입금액': 29.92}],
#                            'PurchasePartner_3': [{'날짜': '2023-09',
#                                                   '매입금액': 6178},
#                                                  {'날짜': '2023-11',
#                                                   '매입금액': 7732},
#                                                  {'날짜': '2024-02',
#                                                   '매입금액': 9729},
#                                                  {'날짜': '2024-03',
#                                                   '매입금액': 6116},
#                                                  {'날짜': '2024-04',
#                                                   '매입금액': 8784},
#                                                  {'날짜': '2024-06',
#                                                   '매입금액': 6718},
#                                                  {'날짜': '2024-07',
#                                                   '매입금액': 8034},
#                                                  {'날짜': '2024-08',
#                                                   '매입금액': 9933},
#                                                  {'날짜': '평균매입금액',
#                                                   '매입금액': 5268.67},
#                                                  {'날짜': '평균지급기일',
#                                                   '매입금액': 41.5}],
#                            'PurchasePartner_4': [{'날짜': '2023-09',
#                                                   '매입금액': 7110},
#                                                  {'날짜': '2023-10',
#                                                   '매입금액': 4834},
#                                                  {'날짜': '2023-12',
#                                                   '매입금액': 7217},
#                                                  {'날짜': '2024-02',
#                                                   '매입금액': 8431},
#                                                  {'날짜': '2024-04',
#                                                   '매입금액': 4960},
#                                                  {'날짜': '2024-05',
#                                                   '매입금액': 9062},
#                                                  {'날짜': '2024-06',
#                                                   '매입금액': 4856},
#                                                  {'날짜': '2024-08',
#                                                   '매입금액': 9795},
#                                                  {'날짜': '평균매입금액',
#                                                   '매입금액': 4688.75},
#                                                  {'날짜': '평균지급기일',
#                                                   '매입금액': 46.83}],
#                            'PurchasePartner_5': [{'날짜': '2023-09',
#                                                   '매입금액': 7269},
#                                                  {'날짜': '2023-10',
#                                                   '매입금액': 4413},
#                                                  {'날짜': '2023-11',
#                                                   '매입금액': 8723},
#                                                  {'날짜': '2023-12',
#                                                   '매입금액': 3477},
#                                                  {'날짜': '2024-02',
#                                                   '매입금액': 3507},
#                                                  {'날짜': '2024-03',
#                                                   '매입금액': 6496},
#                                                  {'날짜': '2024-05',
#                                                   '매입금액': 8511},
#                                                  {'날짜': '2024-06',
#                                                   '매입금액': 8975},
#                                                  {'날짜': '평균매입금액',
#                                                   '매입금액': 4280.92},
#                                                  {'날짜': '평균지급기일',
#                                                   '매입금액': 44.08}],
#                            'PurchasePartner_6': [{'날짜': '2023-11',
#                                                   '매입금액': 8996},
#                                                  {'날짜': '2024-01',
#                                                   '매입금액': 7991},
#                                                  {'날짜': '2024-02',
#                                                   '매입금액': 4370},
#                                                  {'날짜': '2024-03',
#                                                   '매입금액': 9346},
#                                                  {'날짜': '2024-04',
#                                                   '매입금액': 9473},
#                                                  {'날짜': '2024-07',
#                                                   '매입금액': 8721},
#                                                  {'날짜': '평균매입금액',
#                                                   '매입금액': 4074.75},
#                                                  {'날짜': '평균지급기일',
#                                                   '매입금액': 33.33}]},
#  'monthly_top5_sales': {'SalesPartner_3': [{'날짜': '2023-09', '매출금액': 6711},
#                                            {'날짜': '2023-10', '매출금액': 9482},
#                                            {'날짜': '2023-11', '매출금액': 6892},
#                                            {'날짜': '2023-12', '매출금액': 9475},
#                                            {'날짜': '2024-01', '매출금액': 3754},
#                                            {'날짜': '2024-04', '매출금액': 2594},
#                                            {'날짜': '2024-05', '매출금액': 5712},
#                                            {'날짜': '2024-06', '매출금액': 1630},
#                                            {'날짜': '2024-07', '매출금액': 2436},
#                                            {'날짜': '2024-08', '매출금액': 7057},
#                                            {'날짜': '평균매출금액', '매출금액': 4645.25},
#                                            {'날짜': '평균회수기일', '매출금액': 42.92}],
#                         'SalesPartner_4': [{'날짜': '2023-09', '매출금액': 3193},
#                                            {'날짜': '2023-10', '매출금액': 1630},
#                                            {'날짜': '2024-01', '매출금액': 4745},
#                                            {'날짜': '2024-02', '매출금액': 2579},
#                                            {'날짜': '2024-04', '매출금액': 9142},
#                                            {'날짜': '2024-06', '매출금액': 4772},
#                                            {'날짜': '2024-08', '매출금액': 7274},
#                                            {'날짜': '평균매출금액', '매출금액': 2777.92},
#                                            {'날짜': '평균회수기일', '매출금액': 36.17}],
#                         'SalesPartner_5': [{'날짜': '2023-09', '매출금액': 2907},
#                                            {'날짜': '2023-10', '매출금액': 7359},
#                                            {'날짜': '2023-11', '매출금액': 7730},
#                                            {'날짜': '2023-12', '매출금액': 6845},
#                                            {'날짜': '2024-02', '매출금액': 2134},
#                                            {'날짜': '2024-03', '매출금액': 6636},
#                                            {'날짜': '2024-05', '매출금액': 3216},
#                                            {'날짜': '2024-07', '매출금액': 3114},
#                                            {'날짜': '평균매출금액', '매출금액': 3328.42},
#                                            {'날짜': '평균회수기일', '매출금액': 44.83}],
#                         'SalesPartner_6': [{'날짜': '2023-09', '매출금액': 4732},
#                                            {'날짜': '2023-10', '매출금액': 5620},
#                                            {'날짜': '2023-11', '매출금액': 7991},
#                                            {'날짜': '2024-02', '매출금액': 5406},
#                                            {'날짜': '2024-03', '매출금액': 9355},
#                                            {'날짜': '2024-04', '매출금액': 4072},
#                                            {'날짜': '2024-07', '매출금액': 4064},
#                                            {'날짜': '평균매출금액', '매출금액': 3436.67},
#                                            {'날짜': '평균회수기일', '매출금액': 34.92}],
#                         'SalesPartner_7': [{'날짜': '2023-09', '매출금액': 7744},
#                                            {'날짜': '2023-10', '매출금액': 5910},
#                                            {'날짜': '2023-11', '매출금액': 9849},
#                                            {'날짜': '2023-12', '매출금액': 2904},
#                                            {'날짜': '2024-01', '매출금액': 4946},
#                                            {'날짜': '2024-02', '매출금액': 5973},
#                                            {'날짜': '2024-03', '매출금액': 5191},
#                                            {'날짜': '2024-04', '매출금액': 2704},
#                                            {'날짜': '2024-05', '매출금액': 2298},
#                                            {'날짜': '2024-06', '매출금액': 7583},
#                                            {'날짜': '2024-07', '매출금액': 8174},
#                                            {'날짜': '평균매출금액', '매출금액': 5273.0},
#                                            {'날짜': '평균회수기일', '매출금액': 60.83}]}}

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Dict, Any
import logging

# 재현성을 위한 Random seed 설정
np.random.seed(42)

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# 접근 시점 정의
ACCESS_TIME = '2024-09-01'
access_datetime = pd.to_datetime(ACCESS_TIME)

class DataValidationError(Exception):
    """데이터 검증 관련 커스텀 예외"""
    pass

class FinancialStabilityMetricsCalculator:
    """재무 안정성 지표 계산을 위한 메인 클래스"""

    REQUIRED_COLUMNS = [
        '기업명', '날짜', '업종', '총자산', '매출액', '단기차입금', '장기차입금',
        '유동자산', '유동부채', '매출채권', '매입채무', '재고자산'
    ]
    
    COMPANY_COL, DATE_COL, INDUSTRY_COL = '기업명', '날짜', '업종'
    ASSET_COL, REVENUE_COL = '총자산', '매출액'
    SHORT_TERM_DEBT_COL, LONG_TERM_DEBT_COL = '단기차입금', '장기차입금'
    CURRENT_ASSETS_COL, CURRENT_LIABILITIES_COL = '유동자산', '유동부채'
    AR_COL, AP_COL, INVENTORY_COL = '매출채권', '매입채무', '재고자산'

    def __init__(self, df_company_info: pd.DataFrame, target_company_name: str, n_years: int = 3):
        self.df = self._validate_input_data(df_company_info)
        self.target_company_name = target_company_name
        self.n_years = n_years
        self.stability_data = {
            'annual_borrowings': {},
            'annual_liquidity': {},
            'monthly_borrowings': {},
            'monthly_liquidity': {}
        }

    def _validate_input_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """필수 컬럼 및 데이터 유효성 검증 후 데이터 반환"""
        if not all(col in df.columns for col in self.REQUIRED_COLUMNS):
            missing_cols = set(self.REQUIRED_COLUMNS) - set(df.columns)
            raise DataValidationError(f"필수 컬럼 누락: {missing_cols}")
        numeric_columns = [self.ASSET_COL, self.REVENUE_COL, self.SHORT_TERM_DEBT_COL,
                           self.LONG_TERM_DEBT_COL, self.CURRENT_ASSETS_COL, self.CURRENT_LIABILITIES_COL]
        for col in numeric_columns:
            if not pd.to_numeric(df[col], errors='coerce').notnull().all():
                raise DataValidationError(f"숫자가 아닌 값이 포함됨: {col}")
        logger.info("데이터 검증 완료")
        return df[self.REQUIRED_COLUMNS].copy()

    def _prepare_data(self):
        """데이터 전처리 및 필요한 필드 추가"""
        self.df['date'] = pd.to_datetime(self.df[self.DATE_COL])
        self.df['year'] = self.df['date'].dt.year
        self.df['month'] = self.df['date'].dt.month
        
        self.df_company = self.df[self.df[self.COMPANY_COL] == self.target_company_name].reset_index(drop=True)
        if self.df_company.empty:
            raise DataValidationError(f"회사 데이터가 없음: {self.target_company_name}")
        
        self.target_industry = self.df_company[self.INDUSTRY_COL].iloc[0]
        self.df_industry = self.df[self.df[self.INDUSTRY_COL] == self.target_industry].reset_index(drop=True)
        self.latest_date = access_datetime - pd.DateOffset(months=1)
        logger.info(f"데이터 준비 완료 - 기준일자: {self.latest_date.strftime('%Y-%m-%d')}")

    def _calculate_annual_borrowings(self, year: int, estimate: bool = False):
        """연도별 차입금 데이터 계산"""
        current_data = self.df_company[(self.df_company['year'] == year) & ((self.df_company['month'] == self.latest_date.month) if estimate else (self.df_company['month'] == 12))]
        if not current_data.empty:
            short_term_debt = current_data[self.SHORT_TERM_DEBT_COL].iloc[-1]
            long_term_debt = current_data[self.LONG_TERM_DEBT_COL].iloc[-1]
            total_assets = current_data[self.ASSET_COL].iloc[-1]
            debt_ratio = round((short_term_debt + long_term_debt) / total_assets * 100, 2) if total_assets != 0 else 0
        else:
            short_term_debt = long_term_debt = total_assets = debt_ratio = 0

        # Simplify current_industry_data condition
        month_filter = self.latest_date.month if estimate else 12
        current_industry_data = self.df_industry[(self.df_industry['year'] == year) & (self.df_industry['month'] == month_filter)]
        
        individual_ratios = (current_industry_data[self.SHORT_TERM_DEBT_COL] + current_industry_data[self.LONG_TERM_DEBT_COL]) / current_industry_data[self.ASSET_COL]
        individual_ratios = individual_ratios.apply(lambda x: x * 100 if not pd.isna(x) and x != float('inf') else 0)
        industry_debt_ratio = round(individual_ratios[individual_ratios != 0].mean(), 2) if not individual_ratios.isna().all() else 0

        key = f"{year}년(E)" if estimate else f"{year}년"
        self.stability_data['annual_borrowings'][key] = {
            '단기차입금': short_term_debt,
            '장기차입금': long_term_debt,
            '차입금의존도': debt_ratio,
            '업종평균 차입금의존도': industry_debt_ratio
        }

    def _calculate_annual_liquidity(self, year: int, estimate: bool = False):
        """연도별 유동성 데이터 계산"""
        current_data = self.df_company[(self.df_company['year'] == year) & ((self.df_company['month'] == self.latest_date.month) if estimate else (self.df_company['month'] == 12))]
        if not current_data.empty:
            current_assets = current_data[self.CURRENT_ASSETS_COL].iloc[-1]
            current_liabilities = current_data[self.CURRENT_LIABILITIES_COL].iloc[-1]
            current_ratio = round((current_assets / current_liabilities) * 100, 2) if current_liabilities != 0 else 0
        else:
            current_assets = current_liabilities = current_ratio = 0

        # Simplify current_industry_data condition
        month_filter = self.latest_date.month if estimate else 12
        current_industry_data = self.df_industry[(self.df_industry['year'] == year) & (self.df_industry['month'] == month_filter)]

        individual_current_ratios = (current_industry_data[self.CURRENT_ASSETS_COL] / current_industry_data[self.CURRENT_LIABILITIES_COL]) * 100
        individual_current_ratios = individual_current_ratios.apply(lambda x: x if not pd.isna(x) and x != float('inf') else 0)
        industry_current_ratio = round(individual_current_ratios[individual_current_ratios != 0].mean(), 2) if not individual_current_ratios.isna().all() else 0

        key = f"{year}년(E)" if estimate else f"{year}년"
        self.stability_data['annual_liquidity'][key] = {
            '유동자산': current_assets,
            '유동부채': current_liabilities,
            '유동비율': current_ratio,
            '업종평균 유동비율': industry_current_ratio
        }

    def _process_monthly_borrowings(self):
        """최근 12개월 월별 차입금 데이터 계산"""
        past_12_months = pd.date_range(end=self.latest_date + pd.DateOffset(months=1), periods=12, freq='ME')
        for date in past_12_months:
            month_str = date.strftime('%Y-%m')
            current_month = self.df_company[self.df_company['date'].dt.strftime('%Y-%m') == month_str]
            
            if not current_month.empty:
                total_debt = current_month[self.SHORT_TERM_DEBT_COL].iloc[0] + current_month[self.LONG_TERM_DEBT_COL].iloc[0]
                short_term_debt = current_month[self.SHORT_TERM_DEBT_COL].iloc[0]
                revenue = current_month[self.REVENUE_COL].iloc[0]
                debt_to_sales_ratio = round((total_debt / revenue) * 100, 2) if revenue != 0 else 0
            else:
                total_debt = short_term_debt = revenue = debt_to_sales_ratio = 0
            
            current_industry_data = self.df_industry[self.df_industry['date'].dt.strftime('%Y-%m') == month_str]
            industry_debt_to_sales_ratios = ((current_industry_data[self.SHORT_TERM_DEBT_COL] + current_industry_data[self.LONG_TERM_DEBT_COL]) / current_industry_data[self.REVENUE_COL]) * 100
            industry_debt_to_sales_ratios = industry_debt_to_sales_ratios.apply(lambda x: x if not pd.isna(x) and x != float('inf') else 0)
            industry_debt_to_sales_ratio = round(industry_debt_to_sales_ratios[industry_debt_to_sales_ratios != 0].mean(), 2) if not industry_debt_to_sales_ratios.isna().all() else 0
            
            self.stability_data['monthly_borrowings'][month_str] = {
                '총차입금': total_debt,
                '단기차입금': short_term_debt,
                '매출액대비차입비율': debt_to_sales_ratio,
                '업종평균 매출대비차입비율': industry_debt_to_sales_ratio
            }

    def _process_monthly_liquidity(self):
        """최근 12개월 월별 유동성 데이터 계산"""
        past_12_months = pd.date_range(end=self.latest_date + pd.DateOffset(months=1), periods=12, freq='ME')
        for date in past_12_months:
            month_str = date.strftime('%Y-%m')
            current_month = self.df_company[self.df_company['date'].dt.strftime('%Y-%m') == month_str]
            
            if not current_month.empty:
                working_capital = current_month[self.AR_COL].iloc[0] - current_month[self.AP_COL].iloc[0] + current_month[self.INVENTORY_COL].iloc[0]
                revenue = current_month[self.REVENUE_COL].iloc[0]
                working_capital_turnover = round((working_capital / revenue) * 100, 2) if revenue != 0 else 0
            else:
                working_capital = revenue = working_capital_turnover = 0
            
            current_industry_data = self.df_industry[self.df_industry['date'].dt.strftime('%Y-%m') == month_str]
            industry_working_capital_turnovers = ((current_industry_data[self.AR_COL] - current_industry_data[self.AP_COL] + current_industry_data[self.INVENTORY_COL]) / current_industry_data[self.REVENUE_COL]) * 100
            industry_working_capital_turnovers = industry_working_capital_turnovers.apply(lambda x: x if not pd.isna(x) and x != float('inf') else 0)
            industry_working_capital_turnover = round(industry_working_capital_turnovers[industry_working_capital_turnovers != 0].mean(), 2) if not industry_working_capital_turnovers.isna().all() else 0
            
            self.stability_data['monthly_liquidity'][month_str] = {
                '운전자금': working_capital,
                '운전자금회전율': working_capital_turnover,
                '업종평균 운전자금회전율': industry_working_capital_turnover
            }

    def calculate_financial_stability_metrics(self) -> Dict[str, pd.DataFrame]:
        """재무 안정성 지표 계산 실행"""
        self._prepare_data()
        for year_offset in range(1, self.n_years + 1):
            target_year = self.latest_date.year - year_offset
            self._calculate_annual_borrowings(target_year, estimate=False)
            self._calculate_annual_liquidity(target_year, estimate=False)
        self._calculate_annual_borrowings(self.latest_date.year, estimate=True)  # 연말 예상 데이터
        self._calculate_annual_liquidity(self.latest_date.year, estimate=True)
        
        self._process_monthly_borrowings()
        self._process_monthly_liquidity()

        return {
            'latest_year_month': self.latest_date.strftime('%Y-%m'),
            'annual_borrowings': pd.DataFrame(self.stability_data['annual_borrowings']).sort_index(axis=1),
            'annual_liquidity': pd.DataFrame(self.stability_data['annual_liquidity']).sort_index(axis=1),
            'monthly_borrowings': pd.DataFrame(self.stability_data['monthly_borrowings']).sort_index(axis=1),
            'monthly_liquidity': pd.DataFrame(self.stability_data['monthly_liquidity']).sort_index(axis=1)
        }

def preprocess_financial_stability_data(df_company_info: pd.DataFrame, target_company_name: str) -> Dict[str, Any]:
    """재무 안정성 지표 데이터를 전처리하여 JSON 형식으로 변환"""
    calculator = FinancialStabilityMetricsCalculator(df_company_info, target_company_name)
    return calculator.calculate_financial_stability_metrics()


# 'Company_1'에 대한 안정성 지표를 계산
financial_stability_data = preprocess_financial_stability_data(df_company_info, 'Company_1')
# pprint(company_1_stability)


print('#'*10, 'latest_year_month', '#'*10)
pprint(financial_stability_data['latest_year_month'])
print()

print('#'*10, 'annual_borrowings', '#'*10)
pprint(pd.DataFrame(financial_stability_data['annual_borrowings']))
print()

print('#'*10, 'annual_liquidity', '#'*10)
pprint(pd.DataFrame(financial_stability_data['annual_liquidity']))
print()

print('#'*10, 'monthly_borrowings', '#'*10)
pprint(pd.DataFrame(financial_stability_data['monthly_borrowings']))
print()

print('#'*10, 'monthly_liquidity', '#'*10)
pprint(pd.DataFrame(financial_stability_data['monthly_liquidity']))
# Out:
# 2024-11-20 10:57:47,851 - INFO - 데이터 검증 완료
# 2024-11-20 10:57:47,866 - INFO - 데이터 준비 완료 - 기준일자: 2024-08-01
# ########## latest_year_month ##########
# '2024-08'
#
# ########## annual_borrowings ##########
#                2021년    2022년    2023년  2024년(E)
# 단기차입금        2322.00  1185.00  1868.00   2347.00
# 장기차입금        6887.00  3396.00  3863.00   2470.00
# 차입금의존도         28.93    16.70    20.22     18.52
# 업종평균 차입금의존도    29.41    27.74    28.77     25.62
#
# ########## annual_liquidity ##########
#               2021년     2022년     2023년  2024년(E)
# 유동자산       29457.00  15505.00  16203.00  17899.00
# 유동부채       13729.00  13219.00  14683.00  10758.00
# 유동비율         214.56    117.29    110.35    166.38
# 업종평균 유동비율    134.18    123.98    143.09    146.54
#
# ########## monthly_borrowings ##########
#                2023-09   2023-10  2023-11  2023-12  2024-01  2024-02  2024-03  \
# 총차입금           5497.00  11308.00  8111.00  5731.00  10895.0  2931.00  9339.00
# 단기차입금           962.00   2337.00  1662.00  1868.00   4646.0  1903.00   503.00
# 매출액대비차입비율        99.03    173.92   196.73   545.29    457.2    55.24   105.32
# 업종평균 매출대비차입비율   197.29    192.29   254.97   268.29    176.8   185.53   178.32
#
#                2024-04  2024-05  2024-06  2024-07  2024-08
# 총차입금           9743.00  7637.00  5245.00  4125.00  4817.00
# 단기차입금          3367.00  3126.00  3556.00   677.00  2347.00
# 매출액대비차입비율       244.19   341.85   150.63   109.24    85.73
# 업종평균 매출대비차입비율   173.55   210.96   154.12   220.47   167.78
#
# ########## monthly_liquidity ##########
#               2023-09  2023-10  2023-11  2023-12  2024-01  2024-02  2024-03  \
# 운전자금          5643.00  8964.00  9943.00  4408.00  5693.00  3983.00  8381.00
# 운전자금회전율        101.66   137.87   241.16   419.41   238.90    75.07    94.52
# 업종평균 운전자금회전율   163.71   137.26   218.69   197.66   134.08   167.75   148.24
#
#               2024-04  2024-05  2024-06   2024-07  2024-08
# 운전자금          6197.00  7674.00  6948.00  10626.00  3677.00
# 운전자금회전율        155.31   343.51   199.54    281.41    65.44
# 업종평균 운전자금회전율   144.83   169.49   123.75    141.05   133.41

# %% [markdown]
# ## 4. Langchain을 활용한 분석
#
# - cache 설정 : 비용 절감 목적
# - streaming을 위한 custom handler 설정
# - common_llm : 데이터 기반 해석만 하는 자유도가 낮은 gpt-4o-mini
# - load_template : template 읽기
# - determine_strength_weakness : **BPI 계산법 통해 연계 필요**
# - create_analysis_chain : 분석 chain 생성
# - run_analysis : 강/약점을 활용해 분석 시작

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from typing import Dict, Any
import logging
from pprint import pprint
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.schema import StrOutputParser
from langchain.schema.runnable import RunnableParallel, RunnableLambda
from operator import itemgetter
from tabulate import tabulate
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
import random
from tabulate import tabulate
from langchain.output_parsers import PydanticOutputParser
from pydantic import BaseModel, Field

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)


# # 출력 형식 정의
# class FinancialAnalysis(BaseModel):
#     detailed_analysis: str = Field(description="Detailed analysis of the financial data")
#     summary: str = Field(description="Three-sentence summary in Korean")

# # 출력 파서 생성
# parser = PydanticOutputParser(pydantic_object=FinancialAnalysis)  

# OpenAI GPT-4 Mini 모델 설정
common_llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0,
    max_tokens=1000,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

summary_llm = ChatOpenAI(
    model_name="gpt-4o-mini",
    temperature=0,
    max_tokens=500,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

insight_llm = ChatOpenAI(
    model_name="gpt-4o",
    temperature=1.2,
    max_tokens=1000,
    streaming=True,
    # cache=langchain_cache,
    callbacks=[StreamingStdOutCallbackHandler()]
)  

# 디렉토리 설정
CURRENT_DIR = os.getcwd()
PROMPT_PATH = os.path.join(CURRENT_DIR, "prompts")

def load_prompt(file_name: str) -> str:
    file_path = os.path.join(PROMPT_PATH, file_name)
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()
    except FileNotFoundError:
        print(f"Error: Prompt file {file_name} not found.")
        return ""

def determine_strength_weakness(data: pd.DataFrame, company_name: str) -> Dict[str, str]:
    logging.disable(logging.CRITICAL)  # 로깅 임시 비활성화
    growth_data = preprocess_growth_data(data[data['기업명'] == company_name], company_name)
    profitability_data = preprocess_profitability_data(data[data['기업명'] == company_name], company_name)
    partner_stability_data = preprocess_partner_stability_data(data[data['기업명'] == company_name], company_name)
    
    # 임의로 strength와 weakness를 선택하도록 변경
    indicators = ['growth', 'profitability', 'partner_stability', 'financial_stability']
    strength = random.choice(indicators)
    
    # weakness는 strength와 다른 값이 선택되도록 설정
    remaining_indicators = [indicator for indicator in indicators if indicator != strength]
    weakness = random.choice(remaining_indicators)
    
    return {'strength': strength, 'weakness': weakness}

def create_analysis_chain(indicator: str, is_strength: bool, llm: ChatOpenAI, df: pd.DataFrame, company_name: str):
    base_template = load_prompt(f"{indicator}_template.txt")
    additional_prompt = "Perform analysis on positive side." if is_strength else "Perform analysis on negative side."
    full_template = f"{base_template}\n\n{additional_prompt}"
    
    prompt = PromptTemplate.from_template(full_template)
    analysis_chain = prompt | llm | StrOutputParser()
    # analysis_chain = prompt | llm | parser
    
    if indicator == 'growth':
        preprocess_func = preprocess_growth_data
        data_keys = ['latest_year_month', 'annual_revenue', 'annual_assets', 'monthly_revenue', 'monthly_growth']
    elif indicator == 'profitability':
        preprocess_func = preprocess_profitability_data
        data_keys = ['latest_year_month', 'annual_profit', 'annual_margins', 'monthly_profit', 'monthly_margins']
    elif indicator == 'partner_stability':
        preprocess_func = preprocess_partner_stability_data
        data_keys = [
            'latest_year_month',
            'annual_top5_sales',
            'monthly_top5_sales',
            'annual_top5_purchase',
            'monthly_top5_purchase'
        ]
    elif indicator == 'financial_stability':
        preprocess_func = preprocess_financial_stability_data
        data_keys = ['latest_year_month', 'annual_borrowings', 'annual_liquidity', 'monthly_borrowings', 'monthly_liquidity']
    else:
        raise ValueError(f"Unknown indicator: {indicator}")
        
    return RunnableLambda(lambda df: analysis_chain.invoke({
        **{key: preprocess_func(df, company_name)[key] for key in data_keys}
    }))

def run_analysis(df: pd.DataFrame, company_name: str) -> Dict[str, Any]:
    strength_weakness = determine_strength_weakness(df, company_name)
    strength = strength_weakness['strength']
    weakness = strength_weakness['weakness']
    
    strength_chain = create_analysis_chain(strength, True, common_llm, df, company_name)
    weakness_chain = create_analysis_chain(weakness, False, common_llm, df, company_name)
    
    parallel_chain = RunnableParallel({
        'strength_analysis': strength_chain,
        'weakness_analysis': weakness_chain
    })
    
    return {
        'parallel': parallel_chain,
        'strength': strength_chain,
        'weakness': weakness_chain,
        'strength_name': strength,
        'weakness_name': weakness
    }


def print_preprocessed_data(df: pd.DataFrame, company_name: str, metric: str) -> None:
    """전처리된 데이터를 출력"""
    preprocess_func = globals()[f"preprocess_{metric}_data"]
    preprocessed_data = preprocess_func(df, company_name)
    latest_year_month = preprocessed_data['latest_year_month']
    print(f"\n{metric.capitalize()} Data ({latest_year_month} 기준):")
    
    if metric == 'growth':
        # Annual Revenue
        print("\nAnnual Revenue:")
        annual_revenue_df = pd.DataFrame(preprocessed_data['annual_revenue'])
        print(tabulate(annual_revenue_df, headers='keys', tablefmt='pretty'))

        # Annual Assets
        print("\nAnnual Assets:")
        annual_assets_df = pd.DataFrame(preprocessed_data['annual_assets'])
        print(tabulate(annual_assets_df, headers='keys', tablefmt='pretty'))

        # Monthly Revenue
        print("\nMonthly Revenue:")
        monthly_revenue_df = pd.DataFrame(preprocessed_data['monthly_revenue'])
        print(tabulate(monthly_revenue_df, headers='keys', tablefmt='pretty'))

        # Monthly Growth
        print("\nMonthly Growth:")
        monthly_growth_df = pd.DataFrame(preprocessed_data['monthly_growth'])
        print(tabulate(monthly_growth_df, headers='keys', tablefmt='pretty'))

    elif metric == 'profitability':
        # Annual Profit
        print("\nAnnual Profit:")
        annual_profit_df = pd.DataFrame(preprocessed_data['annual_profit'])
        print(tabulate(annual_profit_df, headers='keys', tablefmt='pretty'))

        # Annual Margins
        print("\nAnnual Margins:")
        annual_margins_df = pd.DataFrame(preprocessed_data['annual_margins'])
        print(tabulate(annual_margins_df, headers='keys', tablefmt='pretty'))

        # Monthly Profit
        print("\nMonthly Profit:")
        monthly_profit_df = pd.DataFrame(preprocessed_data['monthly_profit'])
        print(tabulate(monthly_profit_df, headers='keys', tablefmt='pretty'))

        # Monthly Margins
        print("\nMonthly Margins:")
        monthly_margins_df = pd.DataFrame(preprocessed_data['monthly_margins'])
        print(tabulate(monthly_margins_df, headers='keys', tablefmt='pretty'))

    elif metric == 'partner_stability':
        # Annual Top 5 Sales Partners
        print("\nAnnual Top 5 Sales Partners:")
        sales_df = pd.DataFrame(preprocessed_data['annual_top5_sales'])
        sales_df = sales_df.fillna('-')
        print(tabulate(sales_df, headers='keys', tablefmt='pretty', showindex=False))
        
        # Monthly Sales Data
        print("\nMonthly Sales Data (Top 5 Partners):")
        monthly_sales_combined_data = []
        
        for partner, transactions in preprocessed_data['monthly_top5_sales'].items():
            for transaction in transactions:
                transaction['회사명'] = partner
                # 매출금액을 정수로 변환 (평균 관련 컬럼 제외)
                if '평균' not in transaction['날짜'] and '매출금액' in transaction:
                    transaction['매출금액'] = int(transaction['매출금액'])
                monthly_sales_combined_data.append(transaction)
        
        monthly_sales_df = pd.DataFrame(monthly_sales_combined_data)
        
        # 피벗 테이블 생성
        monthly_sales_pivot = monthly_sales_df.pivot_table(
            index='회사명',
            columns='날짜',
            values='매출금액',
            aggfunc='first'
        ).reset_index()
        
        # Annual Top 5 순서대로 정렬하기 위한 순서 리스트 생성
        annual_order = [partner['회사명'] for partner in preprocessed_data['annual_top5_sales'] 
                       if partner['회사명'] not in ['상위 5개 거래처 합계', '기타 거래처 합계']]
        
        # 해당 순서로 정렬
        monthly_sales_pivot['sort_order'] = monthly_sales_pivot['회사명'].map(
            {company: idx for idx, company in enumerate(annual_order)}
        )
        monthly_sales_pivot = monthly_sales_pivot.sort_values('sort_order').drop('sort_order', axis=1)
        
        # 평균값 데이터 준비
        avg_sales = monthly_sales_df[
            monthly_sales_df['날짜'].str.startswith('평균')
        ].copy()
        
        # 평균값 컬럼 추가
        avg_sales_data = {}
        for partner in avg_sales['회사명'].unique():
            partner_data = avg_sales[avg_sales['회사명'] == partner]
            avg_sales_data[partner] = {
                '평균매출금액': partner_data[partner_data['날짜'] == '평균매출금액']['매출금액'].iloc[0],
                '평균회수기일': partner_data[partner_data['날짜'] == '평균회수기일']['매출금액'].iloc[0]
            }
        
        # latest_year_month 추가 및 컬럼 순서 지정
        all_months = sorted([col for col in monthly_sales_pivot.columns if col not in ['회사명', '평균매출금액', '평균회수기일']])
        latest_month = pd.to_datetime(preprocessed_data['latest_year_month']).strftime('%Y-%m')
        
        # 해당 월의 데이터가 있는지 확인
        if latest_month not in all_months:
            monthly_sales_pivot[latest_month] = '-'
            all_months.append(latest_month)
        
        # 컬럼 순서 지정
        monthly_sales_pivot = monthly_sales_pivot[['회사명'] + sorted(all_months)]
        
        # 평균값 컬럼 추가
        monthly_sales_pivot['평균매출금액'] = monthly_sales_pivot['회사명'].map(
            lambda x: avg_sales_data[x]['평균매출금액'] if x in avg_sales_data else '-'
        )
        monthly_sales_pivot['평균회수기일'] = monthly_sales_pivot['회사명'].map(
            lambda x: avg_sales_data[x]['평균회수기일'] if x in avg_sales_data else '-'
        )
        
        # NaN 값을 '-'로 대체
        monthly_sales_pivot = monthly_sales_pivot.fillna('-')
        print(tabulate(monthly_sales_pivot, headers='keys', tablefmt='pretty', showindex=False))

        # Annual Top 5 Purchase Partners
        print("\nAnnual Top 5 Purchase Partners:")
        purchase_df = pd.DataFrame(preprocessed_data['annual_top5_purchase'])
        purchase_df = purchase_df.fillna('-')
        print(tabulate(purchase_df, headers='keys', tablefmt='pretty', showindex=False))
        
        # Monthly Purchase Data (동일한 로직 적용)
        print("\nMonthly Purchase Data (Top 5 Partners):")
        monthly_purchase_combined_data = []
        
        for partner, transactions in preprocessed_data['monthly_top5_purchase'].items():
            for transaction in transactions:
                transaction['회사명'] = partner
                if '평균' not in transaction['날짜'] and '매입금액' in transaction:
                    transaction['매입금액'] = int(transaction['매입금액'])
                monthly_purchase_combined_data.append(transaction)
        
        monthly_purchase_df = pd.DataFrame(monthly_purchase_combined_data)
        
        monthly_purchase_pivot = monthly_purchase_df.pivot_table(
            index='회사명',
            columns='날짜',
            values='매입금액',
            aggfunc='first'
        ).reset_index()
        
        annual_order = [partner['회사명'] for partner in preprocessed_data['annual_top5_purchase'] 
                       if partner['회사명'] not in ['상위 5개 거래처 합계', '기타 거래처 합계']]
        
        monthly_purchase_pivot['sort_order'] = monthly_purchase_pivot['회사명'].map(
            {company: idx for idx, company in enumerate(annual_order)}
        )
        monthly_purchase_pivot = monthly_purchase_pivot.sort_values('sort_order').drop('sort_order', axis=1)
        
        avg_purchase = monthly_purchase_df[
            monthly_purchase_df['날짜'].str.startswith('평균')
        ].copy()
        
        avg_purchase_data = {}
        for partner in avg_purchase['회사명'].unique():
            partner_data = avg_purchase[avg_purchase['회사명'] == partner]
            avg_purchase_data[partner] = {
                '평균매입금액': partner_data[partner_data['날짜'] == '평균매입금액']['매입금액'].iloc[0],
                '평균지급기일': partner_data[partner_data['날짜'] == '평균지급기일']['매입금액'].iloc[0]
            }
        
        all_months = sorted([col for col in monthly_purchase_pivot.columns if col not in ['회사명', '평균매입금액', '평균지급기일']])
        if latest_month not in all_months:
            monthly_purchase_pivot[latest_month] = '-'
            all_months.append(latest_month)
        
        monthly_purchase_pivot = monthly_purchase_pivot[['회사명'] + sorted(all_months)]
        
        monthly_purchase_pivot['평균매입금액'] = monthly_purchase_pivot['회사명'].map(
            lambda x: avg_purchase_data[x]['평균매입금액'] if x in avg_purchase_data else '-'
        )
        monthly_purchase_pivot['평균지급기일'] = monthly_purchase_pivot['회사명'].map(
            lambda x: avg_purchase_data[x]['평균지급기일'] if x in avg_purchase_data else '-'
        )
        
        monthly_purchase_pivot = monthly_purchase_pivot.fillna('-')
        print(tabulate(monthly_purchase_pivot, headers='keys', tablefmt='pretty', showindex=False))

    elif metric == 'financial_stability':
        # Annual Borrowings
        print("\nAnnual Borowings:")
        annual_borrowings_df = pd.DataFrame(preprocessed_data['annual_borrowings'])
        print(tabulate(annual_borrowings_df, headers='keys', tablefmt='pretty'))

        # Annual Liquidity
        print("\nAnnual Liquidity:")
        annual_Liquidity_df = pd.DataFrame(preprocessed_data['annual_liquidity'])
        print(tabulate(annual_Liquidity_df, headers='keys', tablefmt='pretty'))

        # Monthly Borrowings
        print("\nMonthly Borrowings:")
        monthly_borrowings_df = pd.DataFrame(preprocessed_data['monthly_borrowings'])
        print(tabulate(monthly_borrowings_df, headers='keys', tablefmt='pretty'))

        # Monthly Liquidity
        print("\nMonthly Liquidity:")
        monthly_liquidity_df = pd.DataFrame(preprocessed_data['monthly_liquidity'])
        print(tabulate(monthly_liquidity_df, headers='keys', tablefmt='pretty'))

    else:
        print(f"Unknown metric: {metric}")

def merge_analysis_results(strength_result: str, weakness_result: str) -> str:
    """
    강점 분석 결과와 약점 분석 결과를 하나의 문자열로 병합합니다.
    """
    return '\n\n'.join([
        "Strength Analysis:",
        strength_result,
        "Weakness Analysis:",
        weakness_result
    ])
    
def summarize_results(detailed_result: str, llm: ChatOpenAI):
    summary_template = load_prompt(f"summary_template.txt")
    
    prompt = PromptTemplate.from_template(summary_template)
    
    summary_chain = (
        RunnablePassthrough() # Pass detailed_analysis directly to the next step
        | prompt # Fill template with detailed analysis data 
        | llm # Run the chain with LLM for summarization 
        | StrOutputParser() # Parse the output as a clean string
    )
    
    summary_result = summary_chain.invoke({"detailed_analysis": detailed_result})
    
    return summary_result

# %%
strength_chain = create_analysis_chain('financial_stability', True, common_llm, df_company_info, "Company_1")

firm_data = df_company_info[df_company_info['기업명'] == 'Company_1']

print("#"*10, "DETAILS", "#"*10)
strength_result = strength_chain.invoke(firm_data)

# %%
print("#"*10, "SUMMARY", "#"*10)
strength_summary = summarize_results(strength_result, summary_llm)

# %%
weakness_chain = create_analysis_chain('profitability', False, common_llm, df_company_info, "Company_1")

firm_data = df_company_info[df_company_info['기업명'] == 'Company_1']

print("#"*10, "DETAILS", "#"*10)
weakness_result = weakness_chain.invoke(firm_data)

# %%
print("#"*10, "SUMMARY", "#"*10)
weakness_summary = summarize_results(weakness_result, summary_llm)

# %%
final_chain = (
    RunnableParallel({
        'strength_result': itemgetter('strength'),
        'weakness_result': itemgetter('weakness')
    })
    | RunnableLambda(lambda x: {'info': merge_analysis_results(x['strength_result'], x['weakness_result'])})
    | PromptTemplate.from_template(
    """
    Translate and analyze the provided company's strengths and weaknesses:

    {info}

    - Analyze the company's strengths and weaknesses based on the provided data, focusing on key business management insights.
    - Provide specific and actionable recommendations, grounded in the analysis, to capitalize on strengths and address weaknesses.
    - Highlight critical trends and figures as evidence to support your recommendations.
    - Ensure that the recommendations are concise (limited to 5 lines) and translated into Korean in a professional tone.

    # Output Format
    - The response should be in Korean, using natural and connected language.
    - Limit the response to 5 lines or less, with a clear and cohesive structure.
    - Write in a continuous paragraph format that flows smoothly between data points, avoiding lists or bullet points.

    # Guidelines
    1. Base your response objectively on the given data without speculation.
    2. Use specific figures and trends to support your analysis.
    3. Provide practical recommendations that are directly actionable.
    4. Maintain clarity and professionalism in both the analysis and the translation to Korean.
    """
    ) 
    | insight_llm | StrOutputParser()
)
result = final_chain.invoke({
    'strength': strength_result,
    'weakness': weakness_result
})

# %% [markdown]
# ## 5. 경영제언 Session
#
# - gpt-4o로 고품질 모델 활용
# - 창의도를 결정하는 temperature=1.2로 설정
# - max_tokens=500으로 조금 더 긴 text 작성하도록 설정
# - final_chain : 앞에서 분석한 strength와 weakness를 합쳐서 경영제언을 하도록 chain으로 연결
#   - 1안 : 앞에서 streaming으로 분석한 strength_result와 weakness_result를 묶어서 수행 (토큰 비용 아낌)
#   - 2안 : End-to-End로 강단점 분석부터 시작해서 경영 제언까지 수행 (토큰 비용 더 발생)

# %%
# 분석 실행
company_list = df_company_info['기업명'].unique()[:1]
for firm in company_list:
    firm_data = df_company_info[df_company_info['기업명'] == firm]
    chains = run_analysis(df_company_info, firm)
    
    strength_chain = chains['strength']
    weakness_chain = chains['weakness']
    strength_name = chains['strength_name']
    weakness_name = chains['weakness_name']
    
    print(f"\n\n{'#'*10} Preprocessing Strength ({strength_name}) Data for {firm} {'#'*10}")
    print_preprocessed_data(df_company_info, firm, strength_name)
    
    print(f"\n\n{'#'*10} Analyzing Strength ({strength_name}) for {firm} {'#'*10}")
    print("[Detailed_analysis] REASONING start! (blind to users)")
    strength_result = strength_chain.invoke(firm_data)
    print("\n[Detailed_analysis] REASONING ends! (blind to users)")
    print("\n\n")
    print(f"[{strength_name} Summary] FINAL results (observable to users)")
    strength_summary = summarize_results(strength_result, summary_llm)
    # print(strength_result)
    
    print(f"\n\n{'#'*10} Preprocessing Weakness ({weakness_name}) Data for {firm} {'#'*10}")
    print_preprocessed_data(df_company_info, firm, weakness_name)
        
    print(f"\n\n{'#'*10} Analyzing Weakness ({weakness_name}) for {firm} {'#'*10}")
    print("[Detailed_analysis] REASONING start! (blind to users)")
    weakness_result = weakness_chain.invoke(firm_data)
    print("\n[Detailed_analysis] REASONING ends! (blind to users)")
    print("\n\n")
    print(f"[{weakness_name} Summary] FINAL results (observable to users)")
    weakness_summary = summarize_results(weakness_result, summary_llm)
    
    print("\n\n",'#'*10, f'Final Comment for {firm}', '#'*10)    
    final_chain = (
        RunnableParallel({
            'strength_result': itemgetter('strength'),
            'weakness_result': itemgetter('weakness')
        })
        | RunnableLambda(lambda x: {'info': merge_analysis_results(x['strength_result'], x['weakness_result'])})
        | PromptTemplate.from_template(
        """
        Translate and analyze the provided company's strengths and weaknesses:

        {info}

        - Analyze the company's strengths and weaknesses based on the provided data, focusing on key business management insights.
        - Provide specific and actionable recommendations, grounded in the analysis, to capitalize on strengths and address weaknesses.
        - Highlight critical trends and figures as evidence to support your recommendations.
        - Ensure that the recommendations are concise (limited to 5 lines) and translated into Korean in a professional tone.

        # Output Format
        - The response should be in Korean, using natural and connected language.
        - Limit the response to 5 lines or less, with a clear and cohesive structure.
        - Write in a continuous paragraph format that flows smoothly between data points, avoiding lists or bullet points.

        # Guidelines
        1. Base your response objectively on the given data without speculation.
        2. Use specific figures and trends to support your analysis.
        3. Provide practical recommendations that are directly actionable.
        4. Maintain clarity and professionalism in both the analysis and the translation to Korean.
        """
        ) 
        | insight_llm | StrOutputParser()
    )
    result = final_chain.invoke({
        'strength': strength_result,
        'weakness': weakness_result
    })
# Out:
# ########## Preprocessing Strength (growth) Data for Company_1 ##########
#
# Growth Data (2024-08 기준):
#
# Annual Revenue:
# +-----------------------+---------+---------+---------+-----------+
# |                       | 2021년  | 2022년  | 2023년  | 2024년(E) |
# +-----------------------+---------+---------+---------+-----------+
# |        매출액         | 59678.0 | 65102.0 | 58022.0 |  53485.0  |
# |     매출액증가율      | -10.48  |  9.09   | -10.88  |   -7.82   |
# | 업종평균 매출액증가율 |  -5.65  |  1.09   |  -7.4   |  -28.53   |
# +-----------------------+---------+---------+---------+-----------+
#
# Annual Assets:
# +-----------------------+---------+---------+---------+-----------+
# |                       | 2021년  | 2022년  | 2023년  | 2024년(E) |
# +-----------------------+---------+---------+---------+-----------+
# |        총자산         | 31828.0 | 27431.0 | 28348.0 |  26004.0  |
# |     총자산증가율      |  5.17   | -13.81  |  3.34   |   -8.27   |
# | 업종평균 총자산증가율 |  -1.02  |  0.47   |  -0.08  |   -0.27   |
# +-----------------------+---------+---------+---------+-----------+
#
# Monthly Revenue:
# +----------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
# |                | 2023-09 | 2023-10 | 2023-11 | 2023-12 | 2024-01 | 2024-02 | 2024-03 | 2024-04 | 2024-05 | 2024-06 | 2024-07 | 2024-08 |
# +----------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
# |   당월매출액   |  5551   |  6502   |  4123   |  1051   |  2383   |  5306   |  8867   |  3990   |  2234   |  3482   |  3776   |  5619   |
# | 전년동월매출액 |  5040   |  5908   |  6419   |  8771   |  1948   |  1158   |  5332   |  6598   |  8636   |  5867   |  6433   |  4823   |
# +----------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
#
# Monthly Growth:
# +------------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
# |                  | 2023-09 | 2023-10 | 2023-11 | 2023-12 | 2024-01 | 2024-02 | 2024-03 | 2024-04 | 2024-05 | 2024-06 | 2024-07 | 2024-08 |
# +------------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
# |   매출액증가율   |  10.14  |  10.05  | -35.77  | -88.02  |  22.33  |  358.2  |  66.3   | -39.53  | -74.13  | -40.65  |  -41.3  |  16.5   |
# | 누적매출액증가율 |  10.14  |  10.09  |  -6.86  | -34.09  | -30.18  |  -14.8  |  -2.29  |  -8.26  | -19.68  | -21.89  |  -23.9  | -20.99  |
# +------------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+
#
#
# ########## Analyzing Strength (growth) for Company_1 ##########
# [Detailed_analysis] REASONING start! (blind to users)
# The company's financial performance shows a mixed but notably resilient picture, particularly when considering the latest available data. In 2023, the annual revenue (매출액) was reported at 58,022 million won, reflecting a significant decline of 10.88% compared to 2022. However, the estimated revenue for 2024 is projected to decrease further to 53,485 million won, indicating a continued downward trend with an expected decline of 7.82%. Despite these challenges, it is important to note that the industry average revenue growth rate (업종평균 매출액증가율) for 2024 is projected at a much steeper decline of 38.55%, suggesting that the company is faring better than the broader market.
#
# When examining the monthly revenue data, there are fluctuations that indicate potential recovery in certain months. For instance, in March 2024, the monthly revenue reached 8,867 million won, a substantial increase from the previous year's figure of 5,332 million won, resulting in a remarkable monthly growth rate (매출액증가율) of 66.30%. This positive momentum, however, faced challenges in subsequent months, with April 2024 showing a significant drop in revenue to 3,990 million won, down from 6,598 million won in April 2023, leading to a monthly decline of 39.53%. Despite this, the latest month of August 2024 saw a recovery to 5,619 million won, which is still lower than the previous year's figure of 4,823 million won but indicates a positive growth rate of 16.50% compared to the previous month.
#
# In terms of total assets (총자산), the company reported a total of 28,348 million won in 2023, which is a slight increase from 27,431 million won in 2022, reflecting a total asset growth rate (총자산증가율) of 3.34%. However, the estimated total assets for 2024 are projected to decline to 26,004 million won, marking an anticipated decrease of 8.27%. Comparatively, the industry average total asset growth rate (업종평균 총자산증가율) for 2024 is -3.16%, indicating that the company is again performing better than the industry average.
#
# The cumulative revenue growth rate (누적 매출액증가율) also presents a nuanced view of the company's performance. As of August 2024, the cumulative growth rate stands at -20.99%, which, while negative, is less severe than the anticipated industry trends. This suggests that the company is managing to stabilize its revenue performance relative to the broader market.
#
# Overall, while the company faces challenges with declining revenues and total assets, it demonstrates resilience in its performance relative to industry averages. The fluctuations in monthly revenue indicate potential for recovery, particularly with the positive growth observed in March and August 2024. The company's ability to outperform industry averages in both revenue and asset growth rates suggests a strategic positioning that may allow it to navigate through current market difficulties effectively.
# [Detailed_analysis] REASONING ends! (blind to users)
#
#
#
# [growth Summary] FINAL results (observable to users)
# 2023년 회사의 매출액은 58,022백만 원으로 10.88% 감소했으며, 2024년에는 53,485백만 원으로 추가적인 7.82% 감소가 예상됩니다. 그러나 업종 평균 매출액 감소율이 38.55%인 점을 감안할 때, 회사는 상대적으로 더 나은 성과를 보이고 있으며, 특히 2024년 3월에는 매출이 8,867백만 원으로 66.30% 증가하는 긍정적인 신호를 보였습니다. 이러한 변동성을 활용하여 매출 회복 전략을 강화하고, 자산 관리에 집중함으로써 시장의 어려움을 효과적으로 극복할 수 있는 기회를 모색해야 합니다.
#
# ########## Preprocessing Weakness (partner_stability) Data for Company_1 ##########
#
# Partner_stability Data (2024-08 기준):
#
# Annual Top 5 Sales Partners:
# +----------------------+----------+---------------+----------+
# |        회사명        | 신용등급 | 연간_매출금액 | 거래비율 |
# +----------------------+----------+---------------+----------+
# |    SalesPartner_7    |    AA    |     63276     |  20.55   |
# |    SalesPartner_3    |    B     |     55743     |   18.1   |
# |    SalesPartner_6    |   AAA    |     41240     |  13.39   |
# |    SalesPartner_5    |   AA+    |     39941     |  12.97   |
# |    SalesPartner_4    |   BBB+   |     33335     |  10.82   |
# | 상위 5개 거래처 합계 |    -     |    233535     |  75.83   |
# |   기타 거래처 합계   |    -     |     74420     |  24.17   |
# +----------------------+----------+---------------+----------+
#
# Monthly Sales Data (Top 5 Partners):
# +----------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+--------------+
# |     회사명     | 2023-09 | 2023-10 | 2023-11 | 2023-12 | 2024-01 | 2024-02 | 2024-03 | 2024-04 | 2024-05 | 2024-06 | 2024-07 | 2024-08 | 평균매출금액 | 평균회수기일 |
# +----------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+--------------+
# | SalesPartner_7 | 7744.0  | 5910.0  | 9849.0  | 2904.0  | 4946.0  | 5973.0  | 5191.0  | 2704.0  | 2298.0  | 7583.0  | 8174.0  |    -    |    5273.0    |    60.83     |
# | SalesPartner_3 | 6711.0  | 9482.0  | 6892.0  | 9475.0  | 3754.0  |    -    |    -    | 2594.0  | 5712.0  | 1630.0  | 2436.0  | 7057.0  |   4645.25    |    42.92     |
# | SalesPartner_6 | 4732.0  | 5620.0  | 7991.0  |    -    |    -    | 5406.0  | 9355.0  | 4072.0  |    -    |    -    | 4064.0  |    -    |   3436.67    |    34.92     |
# | SalesPartner_5 | 2907.0  | 7359.0  | 7730.0  | 6845.0  |    -    | 2134.0  | 6636.0  |    -    | 3216.0  |    -    | 3114.0  |    -    |   3328.42    |    44.83     |
# | SalesPartner_4 | 3193.0  | 1630.0  |    -    |    -    | 4745.0  | 2579.0  |    -    | 9142.0  |    -    | 4772.0  |    -    | 7274.0  |   2777.92    |    36.17     |
# +----------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+--------------+
#
# Annual Top 5 Purchase Partners:
# +----------------------+----------+---------------+----------+
# |        회사명        | 신용등급 | 연간_매입금액 | 거래비율 |
# +----------------------+----------+---------------+----------+
# |  PurchasePartner_3   |    A+    |     63224     |  17.76   |
# |  PurchasePartner_4   |    B     |     56265     |  15.81   |
# |  PurchasePartner_5   |    BB    |     51371     |  14.43   |
# |  PurchasePartner_6   |   CCC-   |     48897     |  13.74   |
# |  PurchasePartner_1   |   BBB    |     37643     |  10.58   |
# | 상위 5개 거래처 합계 |    -     |    257400     |  72.32   |
# |   기타 거래처 합계   |    -     |     98528     |  27.68   |
# +----------------------+----------+---------------+----------+
#
# Monthly Purchase Data (Top 5 Partners):
# +-------------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+--------------+
# |      회사명       | 2023-09 | 2023-10 | 2023-11 | 2023-12 | 2024-01 | 2024-02 | 2024-03 | 2024-04 | 2024-05 | 2024-06 | 2024-07 | 2024-08 | 평균매입금액 | 평균지급기일 |
# +-------------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+--------------+
# | PurchasePartner_3 | 6178.0  |    -    | 7732.0  |    -    |    -    | 9729.0  | 6116.0  | 8784.0  |    -    | 6718.0  | 8034.0  | 9933.0  |   5268.67    |     41.5     |
# | PurchasePartner_4 | 7110.0  | 4834.0  |    -    | 7217.0  |    -    | 8431.0  |    -    | 4960.0  | 9062.0  | 4856.0  |    -    | 9795.0  |   4688.75    |    46.83     |
# | PurchasePartner_5 | 7269.0  | 4413.0  | 8723.0  | 3477.0  |    -    | 3507.0  | 6496.0  |    -    | 8511.0  | 8975.0  |    -    |    -    |   4280.92    |    44.08     |
# | PurchasePartner_6 |    -    |    -    | 8996.0  |    -    | 7991.0  | 4370.0  | 9346.0  | 9473.0  |    -    |    -    | 8721.0  |    -    |   4074.75    |    33.33     |
# | PurchasePartner_1 | 4951.0  | 4359.0  |    -    | 6393.0  | 9778.0  |    -    |    -    | 3655.0  | 1466.0  |    -    |    -    | 7041.0  |   3136.92    |    29.92     |
# +-------------------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+---------+--------------+--------------+
#
#
# ########## Analyzing Weakness (partner_stability) for Company_1 ##########
# [Detailed_analysis] REASONING start! (blind to users)
# The analysis of the company's business partner stability reveals several concerning trends that could impact future operations. Starting with partner concentration, the top five 매출처 account for a significant 75.83% of total annual sales, indicating a high dependency on a limited number of customers. This concentration poses a risk, especially given that the second-largest customer, SalesPartner_3, has a low 신용등급 of 'B' and has shown a troubling decline in monthly sales, dropping from 9,482 million won in October 2023 to just 2,436 million won in July 2024, a decrease of approximately 74.3%. Such volatility raises concerns about the reliability of this partner and the potential impact on overall revenue.
#
# In terms of credit rating trends, the annual data shows that the top five 매출처 include partners with varying credit ratings, from 'AAA' to 'B'. Notably, SalesPartner_3's low rating and declining sales could signal financial instability, which may affect the company's ability to collect receivables. Furthermore, the average 회수기일 for SalesPartner_3 is 42.92 days, which is relatively short but could become problematic if sales continue to decline. In contrast, SalesPartner_6, with a higher 신용등급 of 'AAA', has a lower average 매출금액 of 3,436.67 million won, indicating that while it is a stable partner, it does not contribute significantly to sales.
#
# Examining the annual 매입처 data, the top five suppliers account for 72.32% of total purchases, with PurchasePartner_3 being the largest at 63,224 million won. However, its 신용등급 of 'A+' is relatively strong, yet the average 지급기일 of 41.5 days suggests that the company may face cash flow challenges if payment terms are not managed effectively. The monthly data shows fluctuations in purchases, with PurchasePartner_3's monthly purchases peaking at 9,933 million won in August 2024, but this is juxtaposed against a lower average 매입금액 of 5,268.67 million won, indicating inconsistent purchasing patterns that could disrupt supply chain stability.
#
# Transaction growth trends also reveal a worrying picture. The average monthly sales for the top five customers have shown significant volatility, particularly for SalesPartner_3, which has seen a drastic drop in sales. This inconsistency is echoed in the supplier data, where PurchasePartner_4's purchases fluctuated significantly, with a peak of 9,795 million won in August 2024, but an average of only 4,688.75 million won, indicating potential supply chain disruptions.
#
# In summary, the company's business partnerships exhibit significant instability, characterized by high partner concentration, concerning credit ratings, inconsistent payment and collection periods, and erratic transaction growth. The reliance on a few key customers, particularly those with low credit ratings, poses a substantial risk to revenue stability. The company must address these vulnerabilities by diversifying its customer base, closely monitoring the financial health of its partners, and managing payment terms to ensure cash flow remains robust.
# [Detailed_analysis] REASONING ends! (blind to users)
#
#
#
# [partner_stability Summary] FINAL results (observable to users)
# 회사의 주요 매출처 5곳이 전체 매출의 75.83%를 차지하며, 특히 두 번째로 큰 고객인 SalesPartner_3의 신용등급이 'B'로 낮고, 매출이 74.3% 감소하여 안정성에 심각한 우려를 낳고 있습니다. 이러한 고객 의존도를 줄이기 위해 고객 기반을 다각화하고, 파트너의 재무 건전성을 면밀히 모니터링하며, 지급 조건을 효과적으로 관리하여 현금 흐름을 확보해야 합니다. 또한, 매입처 5곳이 전체 구매의 72.32%를 차지하고 있어, PurchasePartner_3의 평균 지급기일이 41.5일로 나타나면서 현금 흐름 관리의 중요성이 더욱 부각되고 있습니다.
#
#  ########## Final Comment for Company_1 ##########
# 회사는 전반적 매출 감소와 자산 감소라는 어려움이 있으면서도, 2024년 매출 감소 예상치(-7.82%)와 총자산 감소(-8.27%)가 주력 업계 평균(매출 -38.55%, 자산 -3.16%)보다 우수한 성과를 보여줍니다. 또한 2024년 3월과 8월 매출 회복(각각 66.30%와 16.50%)은 긍정적 조짐을 나타냅니다. 그러나 매출의 75.83%가 주요 5개 고객처에 집중되고, SalesPartner_3의 신용등급 악화(‘B')로 불안정성이 심화되고 있습니다. 주요 고객 및 공급망 다변화를 통한 집중 위험 완화가 필요하며, 신용 등급 관리와 컵새롭적인 계약 조건 강화를 통해 현금 흐름 관리를 돕는 것이 중요합니다.
